# %%
import os

if os.path.exists(''):
    print("YES")

# %%
#Откроем файл на чтение и прочитаем содержимое txt файла в переменную data. Теперь в ней лежат строки из файла.
with open('HP1RUS.TXT', 'r', encoding='utf8') as f:
    data = f.read()

# %%
data[:1000]
# Out:
# '    \n   Джоан Кэтлин Роулинг \n   Гарри Поттер и философский камень \n    \n   Глава первая \n   Мальчик, который выжил \n    \n   Мистер и миссис Дарсли, из дома номер четыре по Бирючинному проезду, могли бы \nс гордостью сказать, что они, слава богу, совершенно нормальные люди. Они были \nбы последними, от кого вы могли бы ожидать участия в чем-нибудь странном и \nтаинственном, потому что они совершенно не одобряли подобной чепухи. \n   Мистер Дарсли работал директором фирмы Граннингз, которая выпускала сверла. Он \nбыл крупный, крепкий мужчина с очень короткой шеей и очень большими усами. \nМиссис Дарсли была худой и светловолосой, зато ее шеи с лихвой хватило бы на \nдвоих. Этим подарком природы она усердно пользовалась, большую часть времени \nшпионя за соседями через садовые изгороди. У Дарсли рос сын Дадли, и они были \nуверены, что лучшего мальчика не сыщешь на всем свете. \n   У Дарсли было все что нужно, но кроме того, у них была тайна, и больше всего \nони боялись, что кто-нибудь раскроет её'

# %%
data = data.replace('\n', '')

# %%
data[:1000]
# Out:
# '       Джоан Кэтлин Роулинг    Гарри Поттер и философский камень        Глава первая    Мальчик, который выжил        Мистер и миссис Дарсли, из дома номер четыре по Бирючинному проезду, могли бы с гордостью сказать, что они, слава богу, совершенно нормальные люди. Они были бы последними, от кого вы могли бы ожидать участия в чем-нибудь странном и таинственном, потому что они совершенно не одобряли подобной чепухи.    Мистер Дарсли работал директором фирмы Граннингз, которая выпускала сверла. Он был крупный, крепкий мужчина с очень короткой шеей и очень большими усами. Миссис Дарсли была худой и светловолосой, зато ее шеи с лихвой хватило бы на двоих. Этим подарком природы она усердно пользовалась, большую часть времени шпионя за соседями через садовые изгороди. У Дарсли рос сын Дадли, и они были уверены, что лучшего мальчика не сыщешь на всем свете.    У Дарсли было все что нужно, но кроме того, у них была тайна, и больше всего они боялись, что кто-нибудь раскроет её. Они с ужасом пре'

# %%
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\alttt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\alttt\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\alttt\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(data)

# %%
[['t'], 'ttt']
# Out:
# [['t'], 'ttt']

# %%
len(sentences)
# Out:
# 6444

# %%
sentences[:10]
# Out:
# ['       Джоан Кэтлин Роулинг    Гарри Поттер и философский камень        Глава первая    Мальчик, который выжил        Мистер и миссис Дарсли, из дома номер четыре по Бирючинному проезду, могли бы с гордостью сказать, что они, слава богу, совершенно нормальные люди.',
#  'Они были бы последними, от кого вы могли бы ожидать участия в чем-нибудь странном и таинственном, потому что они совершенно не одобряли подобной чепухи.',
#  'Мистер Дарсли работал директором фирмы Граннингз, которая выпускала сверла.',
#  'Он был крупный, крепкий мужчина с очень короткой шеей и очень большими усами.',
#  'Миссис Дарсли была худой и светловолосой, зато ее шеи с лихвой хватило бы на двоих.',
#  'Этим подарком природы она усердно пользовалась, большую часть времени шпионя за соседями через садовые изгороди.',
#  'У Дарсли рос сын Дадли, и они были уверены, что лучшего мальчика не сыщешь на всем свете.',
#  'У Дарсли было все что нужно, но кроме того, у них была тайна, и больше всего они боялись, что кто-нибудь раскроет её.',
#  'Они с ужасом представляли, что случится, если кто-то вдруг узнает о Поттерах.',
#  'Миссис Поттер приходилась миссис Дарсли сестрой, которую та не видела вот уже несколько лет; по правде говоря, миссис Дарсли делала вид, что у нее вообще нет сестры, потому что сестра и ее никчемный муж были не похожи на Дарсли настолько, насколько можно.']

# %%
from string import punctuation

s = "a++"

table = str.maketrans("a", "b", '+')
s.translate(table)
# Out:
# 'b'

# %%
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# sentences[2].lower()

# %%
table = str.maketrans("","", punctuation)
simple_preprocess = [s.lower().translate(table) for s in sentences]

# %%
len(simple_preprocess)
# Out:
# 6444

# %%
sentences[10]
# Out:
# 'Дарсли содрогались от мысли, что скажут соседи, если увидят Поттеров.'

# %%
simple_preprocess[10]
# Out:
# 'дарсли содрогались от мысли что скажут соседи если увидят поттеров'

# %%
from nltk.tokenize import word_tokenize
tokenized_words = [word_tokenize(s) for s in simple_preprocess]

# %%
len(tokenized_words)
# Out:
# 6444

# %%
tokenized_words[2:5]
# Out:
# [['мистер',
#   'дарсли',
#   'работал',
#   'директором',
#   'фирмы',
#   'граннингз',
#   'которая',
#   'выпускала',
#   'сверла'],
#  ['он',
#   'был',
#   'крупный',
#   'крепкий',
#   'мужчина',
#   'с',
#   'очень',
#   'короткой',
#   'шеей',
#   'и',
#   'очень',
#   'большими',
#   'усами'],
#  ['миссис',
#   'дарсли',
#   'была',
#   'худой',
#   'и',
#   'светловолосой',
#   'зато',
#   'ее',
#   'шеи',
#   'с',
#   'лихвой',
#   'хватило',
#   'бы',
#   'на',
#   'двоих']]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
[word for sent in tokenized_words for word in sent][:5]
# Out:
# ['джоан', 'кэтлин', 'роулинг', 'гарри', 'поттер']

# %%
','.join([word for sent in tokenized_words for word in sent][:5])
# Out:
# 'джоан,кэтлин,роулинг,гарри,поттер'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ','.join([word for sent in tokenized_words for word in sent])

wordcloud = WordCloud(height=1000, width=2000, background_color='white', colormap='rainbow_r').generate(text)
plt.figure(figsize=(20,20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from nltk.corpus import stopwords

# %%
from nltk.corpus import stopwords

import nltk
nltk.download("stopwords")

russian_stopwords = stopwords.words("russian")
print(russian_stopwords)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\alttt\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
russian_stopwords.append('стоп-слово')

# %%
russian_stopwords
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между',
#  'стоп-слово']

# %%
# removed_stopwords = [word for sent in tokenized_words for word in sent if word not in russian_stopwords]
removed_stopwords = []

for sent in tokenized_words:
    rm_sw_sent = []
    for word in sent:
        if word not in russian_stopwords:
            rm_sw_sent.append(word)
    removed_stopwords.append(rm_sw_sent)

# %%
removed_stopwords
# Out:
# [['джоан',
#   'кэтлин',
#   'роулинг',
#   'гарри',
#   'поттер',
#   'философский',
#   'камень',
#   'глава',
#   'первая',
#   'мальчик',
#   'который',
#   'выжил',
#   'мистер',
#   'миссис',
#   'дарсли',
#   'дома',
#   'номер',
#   'четыре',
#   'бирючинному',
#   'проезду',
#   'могли',
#   'гордостью',
#   'сказать',
#   'слава',
#   'богу',
#   'совершенно',
#   'нормальные',
#   'люди'],
#  ['последними',
#   'кого',
#   'могли',
#   'ожидать',
#   'участия',
#   'чемнибудь',
#   'странном',
#   'таинственном',
#   'совершенно',
#   'одобряли',
#   'подобной',
#   'чепухи'],
#  ['мистер',
#   'дарсли',
#   'работал',
#   'директором',
#   'фирмы',
#   'граннингз',
#   'которая',
#   'выпускала',
#   'сверла'],
#  ['крупный',
#   'крепкий',
#   'мужчина',
#   'очень',
#   'короткой',
#   'шеей',
#   'очень',
#   'большими',
#   'усами'],
#  ['миссис',
#   'дарсли',
#   'худой',
#   'светловолосой',
#   'зато',
#   'шеи',
#   'лихвой',
#   'хватило',
#   'двоих'],
#  ['этим',
#   'подарком',
#   'природы',
#   'усердно',
#   'пользовалась',
#   'большую',
#   'часть',
#   'времени',
#   'шпионя',
#   'соседями',
#   'садовые',
#   'изгороди'],
#  ['дарсли',
#   'рос',
#   'сын',
#   'дадли',
#   'уверены',
#   'лучшего',
#   'мальчика',
#   'сыщешь',
#   'всем',
#   'свете'],
#  ['дарсли',
#   'нужно',
#   'кроме',
#   'тайна',
#   'боялись',
#   'ктонибудь',
#   'раскроет',
#   'её'],
#  ['ужасом', 'представляли', 'случится', 'ктото', 'узнает', 'поттерах'],
#  ['миссис',
#   'поттер',
#   'приходилась',
#   'миссис',
#   'дарсли',
#   'сестрой',
#   'которую',
#   'та',
#   'видела',
#   'несколько',
#   'лет',
#   'правде',
#   'говоря',
#   'миссис',
#   'дарсли',
#   'делала',
#   'вид',
#   'вообще',
#   'сестры',
#   'сестра',
#   'никчемный',
#   'муж',
#   'похожи',
#   'дарсли',
#   'настолько',
#   'насколько'],
#  ['дарсли', 'содрогались', 'мысли', 'скажут', 'соседи', 'увидят', 'поттеров'],
#  ['дарсли', 'знали', 'поттеров', 'маленький', 'сын'],
#  ['это',
#   'одной',
#   'причиной',
#   'держаться',
#   'подальше',
#   'поттеров',
#   'хотели',
#   'дадли',
#   'общался',
#   'подобными',
#   'детьми'],
#  ['наша', 'история', 'началась', 'серый', 'пасмурный', 'вторник'],
#  ['миссис',
#   'мистер',
#   'дарсли',
#   'проснулись',
#   'облачному',
#   'небу',
#   'улице',
#   'никак',
#   'предположить',
#   'вскоре',
#   'всей',
#   'стране',
#   'начнут',
#   'происходить',
#   'странные',
#   'таинственные',
#   'события'],
#  ['мистер',
#   'дарсли',
#   'мурлыкал',
#   'нос',
#   'пока',
#   'выбирал',
#   'работу',
#   'свой',
#   'самый',
#   'скучный',
#   'галстук',
#   'миссис',
#   'дарсли',
#   'радостно',
#   'болтала',
#   'водружая',
#   'орущего',
#   'дадли',
#   'высокий',
#   'стул'],
#  ['никто',
#   'заметил',
#   'большой',
#   'золотистокоричневой',
#   'совы',
#   'промелькнувшей',
#   'окном'],
#  ['половине',
#   'девятого',
#   'мистер',
#   'дарсли',
#   'взял',
#   'свой',
#   'чемоданчик',
#   'чмокнул',
#   'миссис',
#   'дарсли',
#   'щечку',
#   'попытался',
#   'поцеловать',
#   'дадли',
#   'прощание',
#   'безуспешно',
#   'дадли',
#   'приступе',
#   'плохого',
#   'настроения',
#   'швырялся',
#   'кашей'],
#  ['ах', 'разбойник', 'усмехнулся', 'мистер', 'дарсли', 'выходя', 'дома'],
#  ['сел', 'машину', 'выехал', 'улицу'],
#  ['поворачивая',
#   'угол',
#   'заметил',
#   'первый',
#   'признак',
#   'чегото',
#   'особенного',
#   'это',
#   'кошка',
#   'изучающая',
#   'карту'],
#  ['несколько',
#   'секунд',
#   'осознавал',
#   'видел',
#   'резко',
#   'повернул',
#   'голову',
#   'взглянуть'],
#  ['полосатая',
#   'кошка',
#   'стояла',
#   'углу',
#   'бирючинного',
#   'проезда',
#   'никакой',
#   'карты',
#   'поблизости'],
#  ['подумал'],
#  ['должно', 'игра', 'света'],
#  ['мистер', 'дарсли', 'моргнул', 'посмотрел', 'кошку'],
#  ['кошка', 'смотрела'],
#  ['пока',
#   'мистер',
#   'дарсли',
#   'поворачивал',
#   'угол',
#   'следил',
#   'кошкой',
#   'зеркало'],
#  ['читала',
#   'вывеску',
#   'которая',
#   'гласила',
#   'бирючинный',
#   'проезд',
#   'смотрела',
#   'вывеску',
#   'кошки',
#   'могут',
#   'изучать',
#   'карты',
#   'вывески'],
#  ['мистер', 'дарсли', 'встряхнулся', 'выкинул', 'кошку', 'головы'],
#  ['пока',
#   'ехал',
#   'город',
#   'думал',
#   'кроме',
#   'большого',
#   'заказа',
#   'сверла',
#   'который',
#   'собирался',
#   'получить',
#   'сегодня'],
#  ['въезде', 'город', 'новое', 'происшествие', 'вытеснило', 'сверла', 'головы'],
#  ['ждал',
#   'обычной',
#   'утренней',
#   'пробке',
#   'просто',
#   'мог',
#   'заметить',
#   'огромного',
#   'количества',
#   'странно',
#   'одетых',
#   'людей'],
#  ['людей', 'мантиях'],
#  ['мистер',
#   'дарсли',
#   'переносил',
#   'людей',
#   'носящих',
#   'экстравагантную',
#   'одежду',
#   'напяливает',
#   'молодежь'],
#  ['предположил', 'это', 'какаято', 'глупая', 'новая', 'мода'],
#  ['барабанил',
#   'пальцами',
#   'рулю',
#   'взгляд',
#   'упал',
#   'группу',
#   'этих',
#   'чудаков',
#   'поблизости'],
#  ['чтото', 'возбужденно', 'шептали', 'друг', 'другу'],
#  ['пришел',
#   'бешенство',
#   'увидев',
#   'некоторые',
#   'молоды',
#   'мужчина',
#   'вероятно',
#   'старше',
#   'одет',
#   'изумруднозеленую',
#   'мантию'],
#  ['наглость'],
#  ['решил',
#   'это',
#   'какойто',
#   'глупый',
#   'трюк',
#   'скорее',
#   'собирают',
#   'деньги',
#   'чтонибудь',
#   'разумеется'],
#  ['движение',
#   'тронулось',
#   'несколько',
#   'минут',
#   'спустя',
#   'мистер',
#   'дарсли',
#   'прибыл',
#   'автостоянку',
#   'своим',
#   'офисом',
#   'думая',
#   'сверлах'],
#  ['своем',
#   'офисе',
#   'девятом',
#   'этаже',
#   'мистер',
#   'дарсли',
#   'сидел',
#   'спиной',
#   'окну'],
#  ['это', 'трудно', 'сконцентрироваться', 'сверлах', 'этим', 'утром'],
#  ['замечал',
#   'утро',
#   'мимо',
#   'окон',
#   'мелькали',
#   'совы',
#   'люди',
#   'улице',
#   'видели',
#   'показывали',
#   'пальцами',
#   'глазели',
#   'раскрыв',
#   'рты',
#   'головами',
#   'совы',
#   'летают',
#   'тудасюда'],
#  ['большинство', 'видело', 'одной', 'совы', 'ночью'],
#  ['однако',
#   'мистера',
#   'дарсли',
#   'совершенно',
#   'обычное',
#   'утро',
#   'безо',
#   'всяких',
#   'сов'],
#  ['наорал', 'пятерых', 'человек'],
#  ['сделал',
#   'несколько',
#   'важных',
#   'телефонных',
#   'звонков',
#   'немного',
#   'поорал'],
#  ['прекрасном',
#   'настроении',
#   'обеда',
#   'решил',
#   'размять',
#   'ноги',
#   'прогуляться',
#   'дорогу',
#   'купить',
#   'свежую',
#   'булочку',
#   'изюмом'],
#  ['абсолютно',
#   'забыл',
#   'людях',
#   'мантиях',
#   'пока',
#   'столкнулся',
#   'одной',
#   'группой',
#   'около',
#   'булочной'],
#  ['злостью', 'посмотрел', 'проходя', 'мимо'],
#  ['непонятно', 'почему', 'чувствовал', 'неловко'],
#  ['возбужденно',
#   'перешептывались',
#   'заметил',
#   'единой',
#   'коробки',
#   'пожертвований'],
#  ['возвращаясь',
#   'обратно',
#   'большим',
#   'пирогом',
#   'услышал',
#   'обрывок',
#   'разговора',
#   'поттеры',
#   'это',
#   'правда',
#   'слышал',
#   'сын',
#   'гарри',
#   'мистер',
#   'дарсли',
#   'замер'],
#  ['охватил', 'ужас'],
#  ['обернулся', 'желая', 'чтото', 'сказать', 'шептавшим', 'передумал'],
#  ['ринулся',
#   'дорогу',
#   'наверх',
#   'свой',
#   'офис',
#   'велел',
#   'секретарше',
#   'беспокоить',
#   'схватил',
#   'телефон',
#   'кинулся',
#   'набирать',
#   'домашний',
#   'номер',
#   'внезапно',
#   'передумал'],
#  ['положил', 'трубку', 'подергал', 'усы', 'раздумывая', 'это', 'глупо'],
#  ['поттер', 'такая', 'редкая', 'фамилия'],
#  ['наверняка', 'куча', 'поттеров', 'сыновьями', 'имени', 'гарри'],
#  ['подумать', 'уверен', 'племянника', 'зовут', 'гарри'],
#  ['видел', 'мальчика'],
#  ['возможно', 'гарви'],
#  ['гарольд'],
#  ['смысла',
#   'беспокоить',
#   'миссис',
#   'дарсли',
#   'огорчается',
#   'упоминании',
#   'сестре'],
#  ['винил',
#   'такая',
#   'сестра',
#   'равно',
#   'люди',
#   'мантиях',
#   'сегодня',
#   'думать',
#   'сверлах',
#   'значительно',
#   'труднее',
#   'покидая',
#   'здание',
#   'пять',
#   'часов',
#   'обеспокоен',
#   'столкнулся',
#   'кемто',
#   'едва',
#   'выйдя',
#   'улицу'],
#  ['извините', 'пробормотал', 'маленький', 'старичок', 'споткнулся', 'упал'],
#  ['несколько',
#   'секунд',
#   'мистер',
#   'дарсли',
#   'осознал',
#   'старичок',
#   'одет',
#   'фиолетовую',
#   'мантию'],
#  ['казался', 'расстроенным', 'уронили'],
#  ['наоборот',
#   'расплылся',
#   'улыбке',
#   'тонким',
#   'голосом',
#   'звуке',
#   'которого',
#   'прохожий',
#   'обернулся',
#   'сказал',
#   'извиняйтесь',
#   'дорогой',
#   'сэр',
#   'сегодня',
#   'ничто',
#   'огорчит'],
#  ['веселитесь', 'самизнаетекто', 'наконецто', 'исчез'],
#  ['магглы', 'вроде', 'должны', 'праздновать', 'радостный', 'день'],
#  ['старичок',
#   'обнял',
#   'мистера',
#   'дарсли',
#   'талию',
#   'быстро',
#   'убежал',
#   'прочь'],
#  ['мистер', 'дарсли', 'прирос', 'полу'],
#  ['обнял', 'абсолютно', 'незнакомый', 'человек'],
#  ['кроме', 'обозвали', 'магглом', 'это'],
#  ['ошеломлен'],
#  ['поспешил',
#   'машине',
#   'помчался',
#   'домой',
#   'надеясь',
#   'мерещатся',
#   'разные',
#   'глупости',
#   'случалось',
#   'одобрял',
#   'воображение'],
#  ['свернул',
#   'подъездную',
#   'аллею',
#   'дому',
#   'номер',
#   'четыре',
#   'первое',
#   'увидел',
#   'это',
#   'улучшило',
#   'настроения',
#   'полосатая',
#   'кошка',
#   'которой',
#   'столкнулся',
#   'этим',
#   'утром'],
#  ['сидела', 'стене', 'сада'],
#  ['уверен',
#   'это',
#   'та',
#   'самая',
#   'кошка',
#   'точно',
#   'такие',
#   'квадратные',
#   'метки',
#   'вокруг',
#   'глаз'],
#  ['брысь'],
#  ['громко', 'сказал', 'мистер', 'дарсли', 'кошка', 'двинулась', 'места'],
#  ['сурово', 'посмотрела'],
#  ['это', 'нормальное', 'поведение', 'кошки'],
#  ['мистер', 'дарсли', 'очень', 'удивился'],
#  ['пытаясь', 'собраться', 'мыслями', 'вошел', 'дом'],
#  ['решил', 'равно', 'пока', 'говорить', 'жене'],
#  ['миссис', 'дарсли', 'обычный', 'приятный', 'день'],
#  ['рассказала',
#   'ужином',
#   'миссис',
#   'соседки',
#   'проблемы',
#   'дочерью',
#   'дадли',
#   'выучил',
#   'новое',
#   'слово',
#   'буду'],
#  ['мистер', 'дарсли', 'пытался', 'вести', 'обычно'],
#  ['дадли',
#   'уложили',
#   'постель',
#   'вернулся',
#   'гостиную',
#   'вовремя',
#   'услышать',
#   'последний',
#   'репортаж',
#   'вечерних',
#   'новостей'],
#  ['орнитологи', 'повсеместно', 'отметили', 'необычное', 'поведение', 'сов'],
#  ['хотя',
#   'охотятся',
#   'ночью',
#   'днем',
#   'сложно',
#   'увидеть',
#   'сегодня',
#   'сотни',
#   'человек',
#   'наблюдали',
#   'сов',
#   'рассвета'],
#  ['эксперты',
#   'могут',
#   'объяснить',
#   'почему',
#   'совы',
#   'изменили',
#   'своим',
#   'привычкам',
#   'диктор',
#   'позволил',
#   'усмехнуться'],
#  ['очень', 'странно'],
#  ['джим', 'макгаффин', 'расскажет', 'погоде'],
#  ['джим', 'насчет', 'совиного', 'дождя', 'сегодня', 'вечером'],
#  ['оставим',
#   'это',
#   'орнитологам',
#   'тед',
#   'сказал',
#   'метеоролог',
#   'хотя',
#   'смею',
#   'заметить',
#   'сегодня',
#   'совы',
#   'вели',
#   'странно'],
#  ['наблюдатели',
#   'кенте',
#   'йоркшире',
#   'данди',
#   'звонили',
#   'сказать',
#   'вместо',
#   'дождика',
#   'который',
#   'обещал',
#   'вчера',
#   'настоящий',
#   'звездопад'],
#  ['наверное',
#   'люди',
#   'празднуют',
#   'иванов',
#   'день',
#   'лишь',
#   'следующей',
#   'неделе'],
#  ['сегодня', 'вечером', 'скорее', 'сыро'],
#  ['мистер', 'дарсли', 'замер', 'кресле'],
#  ['падающие', 'звезды', 'всей', 'великобританией'],
#  ['совы', 'средь', 'бела', 'дня'],
#  ['таинственные', 'люди', 'мантиях'],
#  ['шепот',
#   'шепот',
#   'поттерах',
#   'миссис',
#   'дарсли',
#   'вошла',
#   'гостиную',
#   'двумя',
#   'чашками',
#   'чая'],
#  ['поделаешь'],
#  ['должен', 'сказать'],
#  ['нервно',
#   'прочистил',
#   'горло',
#   'гм',
#   'петуния',
#   'дорогая',
#   'давно',
#   'получала',
#   'писем',
#   'сестры'],
#  ['ожидал', 'миссис', 'дарсли', 'выглядела', 'потрясенной', 'разозленной'],
#  ['конце', 'концов', 'делали', 'вид', 'вообще', 'сестры'],
#  ['сказала', 'резко'],
#  [],
#  ['странные',
#   'новости',
#   'вечернем',
#   'выпуске',
#   'пробормотал',
#   'мистер',
#   'дарсли'],
#  ['совы',
#   'падающие',
#   'звезды',
#   'городе',
#   'сегодня',
#   'толпа',
#   'смешных',
#   'чудаков'],
#  ['огрызнулась', 'миссис', 'дарсли'],
#  ['просто',
#   'подумал',
#   'это',
#   'имеет',
#   'какоето',
#   'отношение',
#   'знаешь',
#   'компании'],
#  ['миссис', 'дарсли', 'сделала', 'глоток', 'чая', 'сквозь', 'сжатые', 'губы'],
#  ['мистер',
#   'дарсли',
#   'думал',
#   'сможет',
#   'сказать',
#   'слышал',
#   'фамилию',
#   'поттер'],
#  ['решил', 'пробовать'],
#  ['вместо',
#   'сказал',
#   'небрежнее',
#   'сын',
#   'должно',
#   'одного',
#   'возраста',
#   'дадли'],
#  ['возможно', 'ответила', 'миссис', 'дарсли', 'жестко'],
#  ['зовут', 'забыл'],
#  ['говард'],
#  ['гарри',
#   'ужасно',
#   'простонародное',
#   'имя',
#   'хочешь',
#   'знать',
#   'мое',
#   'мнение'],
#  ['согласился', 'мистер', 'дарсли', 'упавшим', 'сердцем'],
#  ['совершенно', 'права'],
#  ['сказал',
#   'единого',
#   'слова',
#   'тему',
#   'пока',
#   'поднимались',
#   'наверх',
#   'спальню'],
#  ['миссис',
#   'дарсли',
#   'принимала',
#   'ванну',
#   'мистер',
#   'дарсли',
#   'подошел',
#   'окну',
#   'выглянул',
#   'сад'],
#  ['кошка', 'сидела'],
#  ['смотрела', 'вниз', 'бирючинный', 'проезд', 'чтото', 'ждала'],
#  ['просто', 'мерещится'],
#  ['это', 'иметь', 'какоето', 'отношение', 'поттерам'],
#  ['выйдет', 'наружу', 'родственники', 'мог', 'думать'],
#  ['дарсли', 'улеглись'],
#  ['миссис',
#   'дарсли',
#   'заснула',
#   'сразу',
#   'мистер',
#   'дарсли',
#   'лежал',
#   'постели',
#   'обдумывая',
#   'снова',
#   'снова'],
#  ['последней',
#   'утешительной',
#   'мыслью',
#   'провалился',
#   'сон',
#   'та',
#   'поттеры',
#   'замешаны',
#   'кого',
#   'причин',
#   'связывать',
#   'дарсли'],
#  ['поттеры',
#   'очень',
#   'знали',
#   'петуния',
#   'думают',
#   'таких',
#   'видел',
#   'способа',
#   'петуния',
#   'могут',
#   'замешаны',
#   'происходило',
#   'зевнул',
#   'перевернулся',
#   'бок',
#   'это',
#   'имеет',
#   'малейшего',
#   'отношения',
#   'ошибался'],
#  ['мистер',
#   'дарсли',
#   'вероятно',
#   'видел',
#   'сны',
#   'кошка',
#   'стене',
#   'выказывала',
#   'никаких',
#   'признаков',
#   'сонливости'],
#  ['сидела',
#   'неподвижно',
#   'словно',
#   'статуя',
#   'глаза',
#   'мигая',
#   'следили',
#   'поворотом',
#   'бирючинного',
#   'проезда'],
#  ['вздрогнула',
#   'соседней',
#   'улице',
#   'хлопнула',
#   'дверца',
#   'машины',
#   'головой',
#   'промелькнули',
#   'две',
#   'совы'],
#  ['самом', 'деле', 'полночь', 'шевельнулась'],
#  ['углу',
#   'улицы',
#   'смотрела',
#   'кошка',
#   'появился',
#   'человек',
#   'появился',
#   'внезапно',
#   'тихо',
#   'подумать',
#   'вырос',
#   'изпод',
#   'земли'],
#  ['кошка', 'шевельнула', 'хвостом', 'прищурилась'],
#  ['такого', 'человека', 'видели', 'бирючинном', 'проезде'],
#  ['высок',
#   'строен',
#   'очень',
#   'стар',
#   'судя',
#   'серебристым',
#   'волосам',
#   'бороде',
#   'длина',
#   'которых',
#   'позволяла',
#   'подоткнуть',
#   'пояс'],
#  ['одет',
#   'длинный',
#   'балахон',
#   'сиреневая',
#   'мантия',
#   'касалась',
#   'земли',
#   'ногах',
#   'ботинки',
#   'пряжками',
#   'высоком',
#   'каблуке'],
#  ['светлые',
#   'голубые',
#   'глаза',
#   'сверкали',
#   'очками',
#   'форме',
#   'полумесяца',
#   'нос',
#   'длинный',
#   'кривой',
#   'точно',
#   'сломан',
#   'минимум',
#   'дважды'],
#  ['человека', 'звали', 'альбус', 'дамблдор'],
#  ['казалось',
#   'альбус',
#   'дамблдор',
#   'понимал',
#   'прибыл',
#   'улицу',
#   'имени',
#   'ботинок',
#   'вызвало',
#   'осуждение'],
#  ['усердно', 'обшаривал', 'свой', 'плащ', 'чтото', 'ища'],
#  ['вероятно',
#   'почувствовал',
#   'смотрят',
#   'внезапно',
#   'поднял',
#   'голову',
#   'взглянул',
#   'кошку',
#   'которая',
#   'наблюдала',
#   'другого',
#   'конца',
#   'улицы'],
#  ['какойто', 'причине', 'вид', 'кошки', 'развеселил'],
#  ['усмехнулся', 'пробормотал', 'следовало', 'знать'],
#  ['нашел', 'искал', 'внутреннем', 'кармане'],
#  ['первый', 'взгляд', 'это', 'казалось', 'серебряной', 'зажигалкой'],
#  ['откинул',
#   'крышку',
#   'щелкнул',
#   'ближайший',
#   'фонарь',
#   'погас',
#   'легким',
#   'хлопком'],
#  ['щелкнул', 'следующий', 'фонарь', 'погрузился', 'тьму'],
#  ['двенадцать',
#   'чиркал',
#   'гасилкой',
#   'пока',
#   'единственным',
#   'светом',
#   'улице',
#   'остались',
#   'маленьких',
#   'уголька',
#   'глаза',
#   'кошки',
#   'следившей'],
#  ['ктото',
#   'выглянул',
#   'окно',
#   'востроглазая',
#   'миссис',
#   'дарсли',
#   'увидела',
#   'происходившего',
#   'тротуаре'],
#  ['дамблдор',
#   'положил',
#   'гасилку',
#   'обратно',
#   'карман',
#   'двинулся',
#   'направлению',
#   'дому',
#   'номер',
#   'четыре',
#   'уселся',
#   'стене',
#   'рядом',
#   'кошкой'],
#  ['смотрел',
#   'некоторое',
#   'время',
#   'произнес',
#   'ожидал',
#   'встретить',
#   'профессор',
#   'макгонагалл'],
#  ['повернулся', 'улыбнуться', 'полосатой', 'кошке', 'исчезла'],
#  ['вместо',
#   'улыбался',
#   'строгой',
#   'женщине',
#   'очках',
#   'точно',
#   'формы',
#   'метки',
#   'вокруг',
#   'кошкиных',
#   'глаз'],
#  ['носила', 'мантию', 'изумрудного', 'цвета'],
#  ['черные', 'волосы', 'стянуты', 'тугой', 'пучок'],
#  ['выглядела', 'заметно', 'раздраженной'],
#  ['узнали', 'это'],
#  ['спросила'],
#  ['дорогой', 'профессор', 'видел', 'кошка', 'сидела', 'прямо'],
#  ['сидели',
#   'прямо',
#   'провели',
#   'кирпичной',
#   'стене',
#   'весь',
#   'день',
#   'заметила',
#   'профессор',
#   'макгонагалл'],
#  ['весь', 'день'],
#  ['праздновали'],
#  ['видел', 'дюжину', 'банкетов', 'вечеринок', 'пока', 'добирался', 'сюда'],
#  ['профессор', 'макгонагалл', 'фыркнула'],
#  ['празднуют',
#   'это',
#   'замечательно',
#   'сказала',
#   'терпящим',
#   'возражений',
#   'тоном'],
#  ['ожидать',
#   'будут',
#   'осторожнее',
#   'магглы',
#   'заметили',
#   'чтото',
#   'происходит'],
#  ['это',
#   'новостях',
#   'кивнула',
#   'головой',
#   'сторону',
#   'темного',
#   'окна',
#   'гостиной',
#   'дарсли'],
#  ['слышала'],
#  ['стаи',
#   'сов',
#   'падающие',
#   'звезды',
#   'тупицы',
#   'вполне',
#   'могут',
#   'чтонибудь',
#   'заметить'],
#  ['падающие', 'звезды', 'кенте', 'держу', 'пари', 'это', 'дедалус', 'диггл'],
#  ['хватало', 'здравого', 'смысла'],
#  ['должны', 'винить', 'сказал', 'дамблдор', 'мягко'],
#  ['мало', 'праздников', 'последние', 'одиннадцать', 'лет'],
#  ['знаю', 'отозвалась', 'профессор', 'макгонагалл', 'раздраженно'],
#  ['это', 'повод', 'потерять', 'голову'],
#  ['люди',
#   'абсолютно',
#   'беззаботны',
#   'ходят',
#   'улицам',
#   'средь',
#   'бела',
#   'дня',
#   'переодевшись',
#   'одежду',
#   'магглов',
#   'это',
#   'вызовет',
#   'слухи',
#   'бросила',
#   'резкий',
#   'взгляд',
#   'сторону',
#   'дамблдора',
#   'надеясь',
#   'чтонибудь',
#   'скажет',
#   'сказал',
#   'продолжила'],
#  ['просто',
#   'замечательно',
#   'самый',
#   'день',
#   'самзнаешькто',
#   'наконецто',
#   'исчез',
#   'магглы',
#   'узнали'],
#  ['предполагаю', 'самом', 'деле', 'исчез', 'дамблдор'],
#  ['это', 'несомненно', 'сказал', 'дамблдор'],
#  ['нам', 'благодарить', 'судьбу'],
#  ['хотите', 'лимонную', 'дольку'],
#  [],
#  ['лимонную', 'дольку'],
#  ['это', 'такие', 'магглские', 'конфеты', 'очень', 'люблю'],
#  ['благодарю',
#   'сказала',
#   'профессор',
#   'макгонагалл',
#   'холодно',
#   'думала',
#   'неподходящий',
#   'момент',
#   'конфет'],
#  ['сказала',
#   'самзнаешькто',
#   'самом',
#   'деле',
#   'исчез',
#   'дорогой',
#   'профессор',
#   'неужели',
#   'здравомыслящий',
#   'человек',
#   'называть',
#   'собственным',
#   'именем'],
#  ['вся',
#   'эта',
#   'самзнаешькто',
#   'чепуха',
#   'одиннадцать',
#   'лет',
#   'пытался',
#   'убедить',
#   'людей',
#   'называть',
#   'нормальным',
#   'именем',
#   'волдеморт',
#   'профессор',
#   'макгонагалл',
#   'вздрогнула',
#   'дамблдор',
#   'чрезвычайно',
#   'занят',
#   'пытаясь',
#   'разлепить',
#   'две',
#   'лимонных',
#   'дольки',
#   'казалось',
#   'заметил'],
#  ['запутается', 'продолжим', 'звать', 'самзнаешькто'],
#  ['видел', 'причины', 'бояться', 'имени', 'волдеморта'],
#  ['знаю',
#   'боялись',
#   'сказала',
#   'профессор',
#   'макгонагалл',
#   'голосе',
#   'раздражение',
#   'смешивалось',
#   'восхищением'],
#  [],
#  ['знают', 'единственный', 'кого', 'самзнаешь', 'волдеморт', 'опасался'],
#  ['льстите', 'спокойно', 'отозвался', 'дамблдор'],
#  ['волдеморта', 'такая', 'сила', 'которая', 'снилась'],
#  ['слишком', 'гм', 'благородны', 'использовать'],
#  ['удача', 'темно'],
#  ['давно',
#   'краснел',
#   'наверное',
#   'тех',
#   'самых',
#   'пор',
#   'мадам',
#   'помфрей',
#   'сказала',
#   'нравятся',
#   'мои',
#   'новые',
#   'наушники'],
#  ['профессор',
#   'макгонагалл',
#   'бросила',
#   'быстрый',
#   'взгляд',
#   'сказала',
#   'совы',
#   'разносят',
#   'слухи'],
#  ['знаете', 'говорят'],
#  ['почему', 'исчез'],
#  ['остановило'],
#  ['казалось',
#   'профессор',
#   'макгонагалл',
#   'подвела',
#   'разговор',
#   'теме',
#   'которую',
#   'хотелось',
#   'обсудить',
#   'изза',
#   'которой',
#   'весь',
#   'день',
#   'провела',
#   'холодной',
#   'кирпичной',
#   'стене',
#   'одна',
#   'кошка',
#   'одна',
#   'женщина',
#   'смогли',
#   'наградить',
#   'таким',
#   'пронзительным',
#   'взглядом'],
#  ['ясно',
#   'говорили',
#   'поверит',
#   'пока',
#   'дамблдор',
#   'скажет',
#   'это',
#   'правда'],
#  ['дамблдор', 'однако', 'занимался', 'следующей', 'конфетой', 'ответил'],
#  ['говорят',
#   'нажимом',
#   'сказала',
#   'вчера',
#   'вечером',
#   'волдеморт',
#   'появился',
#   'лощине',
#   'годрика'],
#  ['пришел', 'найти', 'поттеров'],
#  ['говорят', 'лили', 'джеймс', 'поттеры', 'умерли'],
#  ['дамблдор', 'кивнул'],
#  ['профессор', 'макгонагалл', 'всхлипнула'],
#  ['лили',
#   'джеймс',
#   'могу',
#   'поверить',
#   'хочу',
#   'верить',
#   'ох',
#   'альбус',
#   'дамблдор',
#   'похлопал',
#   'плечу',
#   'знаю',
#   'знаю',
#   'сказал',
#   'грустно'],
#  ['голос', 'профессора', 'макгонагалл', 'дрогнул', 'продолжила', 'это'],
#  ['говорят', 'пытался', 'убить', 'сына', 'гарри'],
#  ['смог'],
#  ['смог', 'убить', 'малыша'],
#  ['никто',
#   'знает',
#   'почему',
#   'говорят',
#   'смог',
#   'убить',
#   'гарри',
#   'поттера',
#   'силы',
#   'волдеморта',
#   'сломлены',
#   'поэтому',
#   'исчез'],
#  ['дамблдор', 'хмуро', 'кивнул'],
#  ['это', 'это', 'правда'],
#  ['запнулась', 'профессор', 'макгонагалл'],
#  ['сделал',
#   'стольких',
#   'людей',
#   'убил',
#   'смог',
#   'убить',
#   'маленького',
#   'мальчика'],
#  ['это',
#   'невероятно',
#   'вещей',
#   'которые',
#   'могли',
#   'остановить',
#   'гарри',
#   'выжил'],
#  ['можем', 'лишь', 'догадываться', 'ответил', 'дамблдор'],
#  ['узнаем'],
#  ['профессор',
#   'макгонагалл',
#   'вытащила',
#   'кружевной',
#   'платочек',
#   'промокнула',
#   'глаза',
#   'очками'],
#  ['дамблдор',
#   'хмыкнул',
#   'вынул',
#   'кармана',
#   'золотые',
#   'часы',
#   'тщательно',
#   'изучил'],
#  ['это', 'очень', 'странные', 'часы'],
#  ['двенадцать',
#   'стрелок',
#   'одной',
#   'цифры',
#   'краю',
#   'двигались',
#   'маленькие',
#   'планеты'],
#  ['однако',
#   'дамблдора',
#   'это',
#   'чтото',
#   'означало',
#   'положил',
#   'часы',
#   'обратно',
#   'карман',
#   'сказал',
#   'хагрид',
#   'опаздывает'],
#  ['полагаю', 'это', 'сказал', 'буду'],
#  ['согласилась', 'профессор', 'макгонагалл'],
#  ['думаю', 'скажете', 'почему', 'выбрали', 'это', 'место', 'возможных'],
#  ['пришел', 'сюда', 'отдать', 'гарри', 'дяде', 'тете'],
#  ['единственная', 'семья'],
#  ['имеете', 'виду', 'людей', 'которые', 'живут'],
#  ['воскликнула',
#   'профессор',
#   'макгонагалл',
#   'вскакивая',
#   'ноги',
#   'показывая',
#   'дом',
#   'номер',
#   'четыре'],
#  ['дамблдор', 'посмеете'],
#  ['наблюдала', 'ними', 'целый', 'день'],
#  ['смогли', 'найти', 'парочку', 'непохожую'],
#  ['сын', 'видела', 'скандалил', 'дорогу', 'магазин', 'требуя', 'конфет'],
#  ['гарри', 'поттер', 'жил'],
#  ['это', 'лучшее', 'место', 'сказал', 'дамблдор', 'твердо'],
#  ['дядя', 'тетя', 'объяснят', 'подрастет'],
#  ['написал', 'письмо'],
#  ['письмо'],
#  ['слабым',
#   'голосом',
#   'повторила',
#   'профессор',
#   'макгонагалл',
#   'усаживаясь',
#   'обратно',
#   'стену'],
#  ['дамблдор', 'самом', 'деле', 'полагаете', 'можете', 'объяснить', 'письмом'],
#  ['люди', 'поймут'],
#  ['знаменит',
#   'легендарен',
#   'удивлюсь',
#   'когданибудь',
#   'сегодняшний',
#   'день',
#   'назовут',
#   'днем',
#   'гарри',
#   'поттера',
#   'нем',
#   'напишут',
#   'книги',
#   'каждый',
#   'ребенок',
#   'мире',
#   'знать',
#   'имя'],
#  ['совершенно',
#   'верно',
#   'согласился',
#   'дамблдор',
#   'серьезно',
#   'глядя',
#   'поверх',
#   'своих',
#   'очков',
#   'форме',
#   'полумесяца'],
#  ['достаточно', 'вскружить', 'голову', 'любому', 'мальчишке'],
#  ['знаменит', 'научится', 'говорить', 'ходить'],
#  ['знаменит', 'причине', 'которой', 'помнит'],
#  ['понимаете', 'подрасти', 'пока', 'готов', 'этому'],
#  ['профессор',
#   'макгонагалл',
#   'открыла',
#   'рот',
#   'передумала',
#   'сглотнула',
#   'сказала',
#   'правы'],
#  ['принесете', 'сюда', 'дамблдор'],
#  ['посмотрела', 'мантию', 'подумала', 'прячет', 'гарри'],
#  ['принесет', 'хагрид'],
#  ['считаете', 'возможным', 'доверять', 'хагриду', 'такое', 'важное', 'дело'],
#  ['доверил', 'хагриду', 'жизнь'],
#  ['говорю',
#   'сердце',
#   'месте',
#   'сказала',
#   'профессор',
#   'макгонагалл',
#   'неохотно'],
#  ['выто', 'знаете', 'довольно', 'беспечен'],
#  ['старается', 'это'],
#  ['низкий', 'грохочущий', 'звук', 'разорвал', 'окружавшую', 'тишину'],
#  ['становился',
#   'громче',
#   'пока',
#   'смотрели',
#   'вверх',
#   'вниз',
#   'улице',
#   'ища',
#   'свет',
#   'фар',
#   'перешел',
#   'рев',
#   'вдвоем',
#   'посмотрели',
#   'вверх',
#   'огромный',
#   'мотоцикл',
#   'возник',
#   'воздуха',
#   'приземлился',
#   'ними'],
#  ['хотя',
#   'мотоцикл',
#   'огромен',
#   'смотрелся',
#   'миниатюрно',
#   'сравнению',
#   'человеком',
#   'который',
#   'сидел',
#   'нем'],
#  ['раза', 'выше', 'любого', 'обычного', 'мужчины', 'пять', 'шире'],
#  ['казался',
#   'очень',
#   'большим',
#   'несуразным',
#   'длинные',
#   'пряди',
#   'густых',
#   'черных',
#   'волос',
#   'борода',
#   'практически',
#   'скрывали',
#   'лицо',
#   'руки',
#   'размером',
#   'крышку',
#   'мусорного',
#   'бака',
#   'ноги',
#   'кожаных',
#   'ботинках',
#   'походили',
#   'маленьких',
#   'дельфинов'],
#  ['своих', 'огромных', 'сильных', 'руках', 'держал', 'охапку', 'одеял'],
#  ['хагрид', 'сказал', 'дамблдор', 'облегченно', 'наконецто'],
#  ['раздобыл', 'мотоцикл'],
#  ['одолжил',
#   'профессор',
#   'дамблдор',
#   'сэр',
#   'сказал',
#   'гигант',
#   'осторожно',
#   'слезая',
#   'мотоцикла'],
#  ['молодой', 'сириус', 'блэк', 'дал', 'сэр'],
#  ['никаких', 'проблем'],
#  ['сэр',
#   'дом',
#   'разрушен',
#   'вытащил',
#   'оттуда',
#   'пока',
#   'начали',
#   'собираться',
#   'магглы'],
#  ['заснул', 'летели', 'бристолем'],
#  ['дамблдор', 'профессор', 'макгонагалл', 'склонились', 'свертком', 'одеял'],
#  ['нем', 'едва', 'видный', 'спал', 'младенец'],
#  ['прядью',
#   'блестящих',
#   'черных',
#   'волос',
#   'лбу',
#   'могли',
#   'увидеть',
#   'чудной',
#   'шрам',
#   'форме',
#   'молнии'],
#  ['это'],
#  ['прошептала', 'профессор', 'макгонагалл'],
#  ['сказал', 'дамблдор'],
#  ['шрам', 'останется', 'навсегда'],
#  ['могли', 'чтонибудь', 'сделать', 'дамблдор'],
#  ['мог', 'стал'],
#  ['шрамы', 'могут', 'пригодиться'],
#  ['самого',
#   'шрам',
#   'левой',
#   'коленкой',
#   'прекрасная',
#   'карта',
#   'лондонского',
#   'метро'],
#  ['хагрид', 'давай', 'сюда', 'нам', 'пора', 'заканчивать', 'этим'],
#  ['взял', 'гарри', 'рук', 'хагрида', 'повернулся', 'дому', 'дарсли'],
#  ['могу', 'могу', 'попрощаться', 'сэр'],
#  ['спросил', 'хагрид'],
#  ['склонил',
#   'большую',
#   'волосатую',
#   'голову',
#   'гарри',
#   'наградил',
#   'мальчика',
#   'колючим',
#   'поцелуем'],
#  ['внезапно', 'взвыл', 'раненая', 'собака'],
#  ['шшшш'],
#  ['прошипела', 'профессор', 'макгонагалл'],
#  ['разбудишь', 'магглов'],
#  ['сссожалею',
#   'всхлипнул',
#   'хагрид',
#   'вынимая',
#   'огромный',
#   'грязный',
#   'платок',
#   'вытирая',
#   'лицо'],
#  ['ннне',
#   'могу',
#   'вынести',
#   'лили',
#   'джеймс',
#   'мертвы',
#   'бедняжка',
#   'гарри',
#   'жить',
#   'магглов',
#   'это',
#   'очень',
#   'печально',
#   'хагрид',
#   'возьми',
#   'руки',
#   'обнаружат',
#   'прошептала',
#   'профессор',
#   'макгонагалл',
#   'робко',
#   'хлопая',
#   'хагрида',
#   'руке',
#   'дамблдор',
#   'перебрался',
#   'стену',
#   'пошел',
#   'парадной',
#   'двери'],
#  ['мягко',
#   'опустил',
#   'гарри',
#   'крыльцо',
#   'вынул',
#   'плаща',
#   'письмо',
#   'положил',
#   'внутрь',
#   'свертка',
#   'вернулся',
#   'обратно'],
#  ['целую',
#   'минуту',
#   'втроем',
#   'стояли',
#   'смотрели',
#   'маленький',
#   'сверток',
#   'плечи',
#   'хагрида',
#   'дрожали',
#   'профессор',
#   'макгонагалл',
#   'яростно',
#   'моргала',
#   'обычно',
#   'горевший',
#   'глазах',
#   'дамблдора',
#   'огонек',
#   'казалось',
#   'пропал'],
#  ['сказал', 'дамблдор'],
#  [],
#  ['нам', 'незачем', 'оставаться'],
#  ['можем', 'успехом', 'пойти', 'присоединиться', 'празднику'],
#  ['глухо', 'согласился', 'хагрид'],
#  ['вернуть', 'сириусу', 'мотоцикл'],
#  ['доброй',
#   'ночи',
#   'профессор',
#   'макгонагалл',
#   'профессор',
#   'дамблдор',
#   'сэр'],
#  ['вытирая',
#   'льющиеся',
#   'слезы',
#   'рукавом',
#   'куртки',
#   'хагрид',
#   'оседлал',
#   'мотоцикл',
#   'нажал',
#   'газ',
#   'ревом',
#   'поднялся',
#   'небо',
#   'исчез',
#   'ночи'],
#  ['ожидаю',
#   'вскоре',
#   'увидеть',
#   'профессор',
#   'макгонагалл',
#   'сказал',
#   'дамблдор',
#   'кивая'],
#  ['профессор', 'макгонагалл', 'шмыгнула', 'носом', 'ответ'],
#  ['дамблдор', 'повернулся', 'пошел', 'вниз', 'улице'],
#  ['углу', 'остановился', 'достал', 'серебряную', 'гасилку'],
#  ['чиркнул',
#   'двенадцать',
#   'фонарей',
#   'вспыхнули',
#   'разом',
#   'бирючинный',
#   'проезд',
#   'внезапно',
#   'озарился',
#   'оранжевым',
#   'светом',
#   'видно',
#   'полосатая',
#   'кошка',
#   'исчезает',
#   'углом',
#   'противоположном',
#   'конце',
#   'улицы'],
#  ['видно', 'сверток', 'одеял', 'крыльце', 'дома', 'номер', 'четыре'],
#  ['удачи', 'гарри', 'прошептал'],
#  ['повернулся', 'пятках', 'взмахнул', 'плащом', 'пропал'],
#  ['легкий',
#   'ветерок',
#   'ерошил',
#   'изгороди',
#   'бирючинного',
#   'проезда',
#   'который',
#   'лежал',
#   'тихий',
#   'опрятный',
#   'черным',
#   'небом',
#   'самое',
#   'последнее',
#   'место',
#   'могли',
#   'произойти',
#   'удивительные',
#   'вещи'],
#  ['гарри', 'поттер', 'пошевелился', 'одеялах', 'просыпаясь'],
#  ['маленькая',
#   'ручка',
#   'сомкнулась',
#   'письме',
#   'лежавшем',
#   'рядом',
#   'спал',
#   'зная',
#   'особенный',
#   'зная',
#   'знаменит',
#   'зная',
#   'несколько',
#   'часов',
#   'разбудит',
#   'крик',
#   'миссис',
#   'дарсли',
#   'откроет',
#   'парадное',
#   'выставить',
#   'бутылки',
#   'изпод',
#   'молока',
#   'зная',
#   'следующие',
#   'несколько',
#   'недель',
#   'щипать',
#   'тыкать',
#   'кузен',
#   'дадли',
#   'мог',
#   'знать',
#   'самый',
#   'момент',
#   'люди',
#   'тайно',
#   'встречающиеся',
#   'всей',
#   'стране',
#   'поднимали',
#   'бокалы',
#   'тихо',
#   'говорили',
#   'друг',
#   'другу',
#   'гарри',
#   'поттера',
#   'мальчика',
#   'который',
#   'выжил'],
#  ['глава',
#   'вторая',
#   'исчезнувшее',
#   'стекло',
#   'десять',
#   'лет',
#   'прошло',
#   'тех',
#   'пор',
#   'дарсли',
#   'проснулись',
#   'обнаружили',
#   'племянника',
#   'своем',
#   'крыльце',
#   'бирючинный',
#   'проезд',
#   'капельки',
#   'изменился'],
#  ['солнце',
#   'поднималось',
#   'такими',
#   'аккуратными',
#   'садиками',
#   'освещало',
#   'латунную',
#   'табличку',
#   'номером',
#   'четыре',
#   'парадной',
#   'двери',
#   'дома',
#   'дарсли',
#   'оно',
#   'прокрадывалось',
#   'гостиную',
#   'которая',
#   'осталась',
#   'вечер',
#   'мистер',
#   'дарсли',
#   'смотрел',
#   'роковой',
#   'репортаж',
#   'совах'],
#  ['лишь',
#   'фотографиям',
#   'каминной',
#   'полке',
#   'определить',
#   'сколько',
#   'времени',
#   'прошло'],
#  ['десять',
#   'лет',
#   'назад',
#   'множество',
#   'фотографий',
#   'чегото',
#   'похожего',
#   'большой',
#   'розовый',
#   'мяч',
#   'разноцветных',
#   'чепчиках',
#   'дадли',
#   'дарсли',
#   'вырос',
#   'фотографиях',
#   'увидеть',
#   'большого',
#   'светловолосого',
#   'мальчика',
#   'первом',
#   'велосипеде',
#   'ярмарочной',
#   'карусели',
#   'играющего',
#   'отцом',
#   'компьютере',
#   'обнимку',
#   'матерью'],
#  ['комнате', 'намека', 'доме', 'живет', 'мальчик'],
#  ['хотя',
#   'гарри',
#   'поттер',
#   'жил',
#   'данный',
#   'момент',
#   'спал',
#   'хотя',
#   'спать',
#   'оставалось',
#   'недолго'],
#  ['тетя',
#   'петуния',
#   'проснулась',
#   'резкий',
#   'голос',
#   'первым',
#   'услышал',
#   'день'],
#  ['вставай'],
#  ['вставай'],
#  ['гарри', 'сел', 'постели'],
#  ['тетя', 'колотила', 'дверь'],
#  ['вставай'],
#  ['крикнула'],
#  ['гарри', 'слышал', 'ушла', 'кухню', 'ставила', 'плиту', 'сковородку'],
#  ['перекатился', 'спину', 'попытался', 'вспомнить', 'свой', 'сон'],
#  ['это', 'отличный', 'сон'],
#  ['летающим', 'мотоциклом'],
#  ['странное', 'чувство', 'когдато', 'видел', 'сон'],
#  ['тетя', 'дверью', 'вернулась'],
#  ['встал'],
#  ['требовательно', 'спросила'],
#  ['ответил', 'гарри'],
#  ['давай', 'поднимайся', 'хочу', 'последил', 'беконом'],
#  ['попробуй', 'сжечь', 'день', 'рождения', 'дадли', 'должно', 'безупречно'],
#  ['гарри', 'застонал'],
#  ['сказал'],
#  ['крикнула', 'тетя', 'изза', 'двери'],
#  ['день', 'рождения', 'дадли', 'мог', 'забыть'],
#  ['гарри', 'медленно', 'вылез', 'изпод', 'одеяла', 'начал', 'искать', 'носки'],
#  ['нашел', 'парочку', 'кроватью', 'снял', 'паука', 'надел'],
#  ['гарри', 'привык', 'паукам', 'чулане', 'лестницей', 'спал', 'полно'],
#  ['оделся', 'прошел', 'коридору', 'кухню'],
#  ['стола', 'видно', 'грудой', 'подарков', 'дадли'],
#  ['похоже',
#   'дадли',
#   'получил',
#   'новый',
#   'компьютер',
#   'который',
#   'хотел',
#   'говоря',
#   'втором',
#   'телевизоре',
#   'спортивном',
#   'велосипеде'],
#  ['гарри',
#   'мог',
#   'понять',
#   'дадли',
#   'велосипед',
#   'толст',
#   'ненавидел',
#   'физические',
#   'упражнения',
#   'единственное',
#   'любил',
#   'это',
#   'когонибудь',
#   'бить'],
#  ['дадли', 'любил', 'бить', 'гарри', 'обычно', 'мог', 'поймать'],
#  ['гарри', 'очень', 'быстрым', 'хотя', 'первый', 'взгляд', 'предположить'],
#  ['возможно',
#   'изза',
#   'жил',
#   'темном',
#   'чулане',
#   'гарри',
#   'невысок',
#   'легок',
#   'своего',
#   'возраста'],
#  ['выглядел',
#   'меньше',
#   'тоньше',
#   'самом',
#   'деле',
#   'вся',
#   'одежда',
#   'доставалась',
#   'дадли',
#   'дадли',
#   'четыре',
#   'раза'],
#  ['гарри',
#   'узкое',
#   'лицо',
#   'острые',
#   'коленки',
#   'черные',
#   'волосы',
#   'яркие',
#   'зеленые',
#   'глаза'],
#  ['носил',
#   'круглые',
#   'очки',
#   'перемотанные',
#   'огромным',
#   'количеством',
#   'скотча',
#   'дадли',
#   'обожал',
#   'бить',
#   'нос'],
#  ['единственной',
#   'вещью',
#   'своей',
#   'внешности',
#   'которую',
#   'гарри',
#   'одобрял',
#   'тонкий',
#   'шрам',
#   'лбу',
#   'форме',
#   'молнии'],
#  ['жизнь',
#   'сколько',
#   'помнил',
#   'первый',
#   'вопрос',
#   'который',
#   'задал',
#   'тете',
#   'петунии',
#   'откуда',
#   'взялся',
#   'шрам'],
#  ['заработал',
#   'автомобильной',
#   'катастрофе',
#   'погибли',
#   'твои',
#   'родители',
#   'сказала'],
#  ['задавай', 'вопросов'],
#  ['задавай',
#   'вопросов',
#   'это',
#   'первое',
#   'правило',
#   'спокойной',
#   'жизни',
#   'семье',
#   'дарсли'],
#  ['дядя', 'вернон', 'вошел', 'кухню', 'гарри', 'переворачивал', 'бекон'],
#  ['причешись'],
#  ['гавкнул', 'качестве', 'утреннего', 'приветствия'],
#  ['примерно',
#   'неделю',
#   'дядя',
#   'вернон',
#   'отрывал',
#   'нос',
#   'газеты',
#   'объявлял',
#   'гарри',
#   'требуется',
#   'стрижка'],
#  ['вероятно',
#   'гарри',
#   'стригли',
#   'мальчишек',
#   'классе',
#   'вместе',
#   'взятых',
#   'безрезультатно'],
#  ['волосы',
#   'бесполезно',
#   'укладывать',
#   'торчали',
#   'стороны',
#   'словно',
#   'солома'],
#  ['гарри',
#   'поджаривал',
#   'яичницу',
#   'тому',
#   'времени',
#   'дадли',
#   'мать',
#   'появились',
#   'кухне'],
#  ['дадли', 'рос', 'очень', 'похожим', 'дядю', 'вернона'],
#  ['круглое',
#   'розовое',
#   'лицо',
#   'маленькие',
#   'блеклоголубые',
#   'глаза',
#   'толстые',
#   'светлые',
#   'волосы',
#   'гладко',
#   'лежали',
#   'большой',
#   'круглой',
#   'голове'],
#  ['тетя',
#   'петуния',
#   'часто',
#   'говорила',
#   'дадли',
#   'похож',
#   'ангелочка',
#   'гарри',
#   'часто',
#   'говорил',
#   'дадли',
#   'похож',
#   'хрюшу',
#   'рюшах'],
#  ['гарри',
#   'поставил',
#   'тарелки',
#   'яичницей',
#   'беконом',
#   'стол',
#   'это',
#   'трудно',
#   'нем',
#   'оставалось',
#   'мало',
#   'места'],
#  ['это', 'время', 'дадли', 'подсчитывал', 'свои', 'подарки'],
#  ['лицо', 'вытянулось'],
#  ['тридцать', 'шесть', 'сказал', 'глядя', 'отца', 'мать'],
#  ['меньше', 'прошлом', 'году'],
#  ['дорогой',
#   'посчитал',
#   'подарок',
#   'тетушки',
#   'мардж',
#   'посмотри',
#   'большим',
#   'папочки',
#   'мамочки'],
#  ['тридцать', 'семь', 'сказал', 'дадли', 'багровея'],
#  ['гарри',
#   'видя',
#   'дадли',
#   'готов',
#   'впасть',
#   'ярость',
#   'начал',
#   'жевать',
#   'свой',
#   'бекон',
#   'скоростью',
#   'землеройки',
#   'боясь',
#   'дадли',
#   'перевернет',
#   'стол'],
#  ['тетя',
#   'петуния',
#   'очевидно',
#   'почувствовала',
#   'опасность',
#   'сказала',
#   'купим',
#   'тебе',
#   'поедем',
#   'город',
#   'сегодня'],
#  ['тебе', 'это', 'солнышко'],
#  ['подарка'],
#  ['порядке'],
#  ['дадли', 'немного', 'подумал'],
#  ['это', 'трудно'],
#  ['устав',
#   'усилий',
#   'медленно',
#   'произнес',
#   'тридцать',
#   'тридцать',
#   'тридцать',
#   'девять',
#   'сладкий',
#   'сказала',
#   'тетя',
#   'петуния'],
#  ['дадли', 'тяжело', 'уселся', 'схватил', 'ближайший', 'сверток'],
#  [],
#  ['дядя', 'вернон', 'усмехнулся', 'разбойник', 'прогадает', 'весь'],
#  ['держать', 'дадлюша'],
#  ['потрепал', 'дадли', 'голове'],
#  ['момент',
#   'зазвонил',
#   'телефон',
#   'тетя',
#   'петуния',
#   'ушла',
#   'взять',
#   'трубку',
#   'пока',
#   'гарри',
#   'дядя',
#   'вернон',
#   'наблюдали',
#   'дадли',
#   'разворачивает',
#   'спортивный',
#   'велосипед',
#   'видеокамеру',
#   'радиоуправляемую',
#   'модель',
#   'самолета',
#   'шестнадцать',
#   'новых',
#   'компьютерных',
#   'игр',
#   'видеомагнитофон'],
#  ['снимал',
#   'оберточную',
#   'бумагу',
#   'золотых',
#   'наручных',
#   'часов',
#   'тетя',
#   'петуния',
#   'вернулась'],
#  ['выглядела', 'одновременно', 'злой', 'озабоченной'],
#  ['плохие', 'новости', 'вернон', 'сказала'],
#  ['миссис', 'фигг', 'сломала', 'ногу'],
#  ['сможет', 'приглядеть', 'кивнула', 'головой', 'сторону', 'гарри'],
#  ['дадли', 'ужасе', 'открыл', 'рот', 'гарри', 'екнуло', 'сердце'],
#  ['каждый',
#   'год',
#   'день',
#   'рожденья',
#   'дадли',
#   'родители',
#   'везли',
#   'другом',
#   'город',
#   'парк',
#   'приключений',
#   'ресторанчик',
#   'гамбургеров',
#   'кино'],
#  ['каждый',
#   'год',
#   'гарри',
#   'оставляли',
#   'миссис',
#   'фигг',
#   'сумасшедшей',
#   'старой',
#   'дамой',
#   'которая',
#   'жила',
#   'две',
#   'улицы'],
#  ['гарри', 'ненавидел', 'дом'],
#  ['весь',
#   'пропах',
#   'капустой',
#   'миссис',
#   'фигг',
#   'заставляла',
#   'разглядывать',
#   'фотографии',
#   'кошек',
#   'какие',
#   'когдалибо'],
#  [],
#  ['спросила', 'тетя', 'петуния', 'гневно', 'глядя', 'гарри', 'это', 'виноват'],
#  ['гарри',
#   'знал',
#   'нужно',
#   'сожалеть',
#   'миссис',
#   'фигг',
#   'сломала',
#   'ногу',
#   'это',
#   'нелегко',
#   'особенно',
#   'напомнил',
#   'пройдет',
#   'год',
#   'вынужден',
#   'смотреть',
#   'тиббла',
#   'снежка',
#   'лапушку',
#   'пуфика',
#   'снова'],
#  ['можем', 'позвонить', 'мардж', 'предложил', 'дядя', 'вернон'],
#  ['говори', 'глупостей', 'ненавидит', 'мальчишку'],
#  ['дарсли',
#   'часто',
#   'говорили',
#   'гарри',
#   'чемто',
#   'противным',
#   'вроде',
#   'слизняка',
#   'понимал'],
#  ['насчет', 'кактамеезовут', 'твоей', 'подруги', 'ивонн'],
#  ['отпуске', 'майорке', 'ответила', 'тетя', 'петуния'],
#  ['могли',
#   'оставить',
#   'дома',
#   'сказал',
#   'гарри',
#   'надеждой',
#   'смог',
#   'посмотреть',
#   'телевизор',
#   'захочет',
#   'поиграть',
#   'компьютере',
#   'дадли'],
#  ['тетя', 'петуния', 'скривилась', 'съела', 'лимон'],
#  ['вернуться', 'обнаружить', 'дом', 'руинах'],
#  ['огрызнулась'],
#  ['взорву', 'дом', 'возразил', 'гарри', 'слушали'],
#  ['думаю',
#   'могли',
#   'взять',
#   'зоопарк',
#   'сказала',
#   'тетя',
#   'петуния',
#   'медленно'],
#  ['оставить',
#   'машине',
#   'машина',
#   'новая',
#   'дадли',
#   'начал',
#   'громко',
#   'плакать'],
#  ['самом',
#   'деле',
#   'плакал',
#   'прошли',
#   'годы',
#   'тех',
#   'пор',
#   'плакал',
#   'понастоящему',
#   'знал',
#   'скорчит',
#   'рожу',
#   'повоет',
#   'мать',
#   'даст',
#   'угодно'],
#  ['дадли', 'маленький', 'плачь'],
#  ['мамуля', 'позволит', 'испортить', 'твой', 'день', 'рождения'],
#  ['воскликнула', 'заключила', 'сына', 'объятия'],
#  ['хочууу', 'оон', 'ехал'],
#  ['выкрикнул', 'дадли', 'громкими', 'ненатуральными', 'всхлипами'],
#  ['портит'],
#  ['мерзко', 'усмехнулся', 'гарри', 'выглянув', 'материнских', 'объятий'],
#  ['момент', 'зазвонил', 'дверной', 'звонок'],
#  ['боже'],
#  ['сказала',
#   'тетя',
#   'петуния',
#   'отчаянии',
#   'минуту',
#   'спустя',
#   'лучший',
#   'друг',
#   'дадли',
#   'пирс',
#   'полкисс',
#   'вошел',
#   'кухню',
#   'своей',
#   'матерью'],
#  ['пирс', 'тощим', 'мальчишкой', 'крысиным', 'лицом'],
#  ['обычно', 'держал', 'людей', 'руки', 'пока', 'дадли', 'бил'],
#  ['дадли', 'сразу', 'перестал', 'притворяться', 'плачет'],
#  ['полчаса',
#   'гарри',
#   'который',
#   'мог',
#   'поверить',
#   'удачу',
#   'сидел',
#   'заднем',
#   'сиденье',
#   'машины',
#   'дарсли',
#   'вместе',
#   'дадли',
#   'пирсом',
#   'дороге',
#   'зоопарк',
#   'первый',
#   'жизни'],
#  ['тетя',
#   'дядя',
#   'смогли',
#   'придумать',
#   'выехать',
#   'дядя',
#   'вернон',
#   'отвел',
#   'гарри',
#   'сторону',
#   'предупреждаю',
#   'сказал',
#   'опуская',
#   'свое',
#   'большое',
#   'красное',
#   'лицо',
#   'вровень',
#   'лицом',
#   'гарри'],
#  ['предупреждаю',
#   'парень',
#   'какиенибудь',
#   'шуточки',
#   'угодно',
#   'будешь',
#   'сидеть',
#   'чулане',
#   'рождества'],
#  ['собираюсь', 'делать', 'сказал', 'гарри'],
#  ['правда', 'дядя', 'вернон', 'поверил'],
#  ['никто', 'верил'],
#  ['дело',
#   'вокруг',
#   'гарри',
#   'часто',
#   'происходили',
#   'странные',
#   'вещи',
#   'бесполезно',
#   'убеждать',
#   'дарсли',
#   'причина'],
#  ['однажды',
#   'тетя',
#   'петуния',
#   'устав',
#   'гарри',
#   'приходит',
#   'парикмахерской',
#   'взяла',
#   'пару',
#   'кухонных',
#   'ножниц',
#   'постригла',
#   'наголо',
#   'оставив',
#   'челку',
#   'спрятать',
#   'ужасный',
#   'шрам'],
#  ['дадли',
#   'хихикал',
#   'весь',
#   'вечер',
#   'гарри',
#   'провел',
#   'ночь',
#   'думая',
#   'завтрашней',
#   'школе',
#   'смеялись',
#   'мешковатую',
#   'одежду',
#   'очки',
#   'перемотанные',
#   'скотчем'],
#  ['однако',
#   'проснулся',
#   'следующее',
#   'утро',
#   'волосы',
#   'точно',
#   'длины',
#   'стрижки'],
#  ['это',
#   'неделю',
#   'просидел',
#   'чулане',
#   'хотя',
#   'пытался',
#   'объяснить',
#   'знает',
#   'отросли',
#   'быстро'],
#  ['тетя',
#   'петуния',
#   'пыталась',
#   'надеть',
#   'отвратительный',
#   'старый',
#   'свитер',
#   'дадли',
#   'коричневый',
#   'оранжевыми',
#   'помпонами',
#   'сильнее',
#   'пыталась',
#   'натянуть',
#   'голову',
#   'гарри',
#   'казалось',
#   'меньше',
#   'становился',
#   'тех',
#   'пор',
#   'пока',
#   'стал',
#   'впору',
#   'кукле',
#   'никак',
#   'гарри'],
#  ['тетя',
#   'петуния',
#   'решила',
#   'сел',
#   'стирке',
#   'большому',
#   'облегчению',
#   'гарри',
#   'наказали'],
#  ['стороны',
#   'большие',
#   'неприятности',
#   'оказался',
#   'крыше',
#   'школьной',
#   'кухни'],
#  ['банда',
#   'дадли',
#   'гонялась',
#   'обычно',
#   'всеобщему',
#   'удивлению',
#   'оказался',
#   'сидящим',
#   'трубе'],
#  ['дарсли',
#   'получили',
#   'гневное',
#   'письмо',
#   'директора',
#   'котором',
#   'говорилось',
#   'взбирается',
#   'школьные',
#   'здания'],
#  ['пытался',
#   'сделать',
#   'кричал',
#   'дяде',
#   'вернону',
#   'закрытую',
#   'дверь',
#   'чулана',
#   'это',
#   'прыгнуть',
#   'большой',
#   'мусорный',
#   'бак',
#   'около',
#   'черного',
#   'входа',
#   'кухню'],
#  ['гарри', 'предполагал', 'ветер', 'подхватил', 'прыжке', 'поднял', 'крышу'],
#  ['сегодня', 'шло', 'отлично'],
#  ['это',
#   'стоило',
#   'провести',
#   'день',
#   'дадли',
#   'пирсом',
#   'гдето',
#   'вне',
#   'школы',
#   'чулана',
#   'пахнущей',
#   'капустой',
#   'гостиной',
#   'миссис',
#   'фигг'],
#  ['пока', 'ехали', 'дядя', 'вернон', 'жаловался', 'тете', 'петунии'],
#  ['вообще',
#   'любил',
#   'жаловаться',
#   'служащих',
#   'офисе',
#   'гарри',
#   'совет',
#   'гарри',
#   'банк',
#   'гарри',
#   'это',
#   'любимые',
#   'темы'],
#  ['сегодня', 'утром', 'туда', 'попали', 'мотоциклы'],
#  ['пролетают',
#   'ревом',
#   'мимо',
#   'сумасшедшие',
#   'молодые',
#   'хулиганы',
#   'сказал',
#   'обогнал',
#   'мотоцикл'],
#  ['снился', 'сон', 'мотоцикл', 'внезапно', 'вспомнил', 'гарри'],
#  ['летал'],
#  ['дядя', 'вернон', 'врезался', 'машину', 'впереди'],
#  ['повернул',
#   'гарри',
#   'лицо',
#   'похожее',
#   'отбивную',
#   'усами',
#   'заорал',
#   'мотоциклы',
#   'летают'],
#  ['дадли', 'пирс', 'захихикали'],
#  ['знаю', 'сказал', 'гарри'],
#  ['это', 'просто', 'сон'],
#  ['жалел', 'вообще', 'открыл', 'рот'],
#  ['чтото',
#   'дарсли',
#   'ненавидели',
#   'вопросов',
#   'это',
#   'говорил',
#   'вещах',
#   'которые',
#   'вели',
#   'следует',
#   'неважно',
#   'это',
#   'сон',
#   'мультик',
#   'вероятно',
#   'думали',
#   'могут',
#   'появиться',
#   'опасные',
#   'идеи'],
#  ['стояла', 'очень', 'солнечная', 'суббота', 'зоопарке', 'куча', 'народу'],
#  ['дарсли',
#   'купили',
#   'дадли',
#   'пирсу',
#   'большому',
#   'шоколадному',
#   'мороженому',
#   'входе',
#   'улыбающаяся',
#   'дама',
#   'киоске',
#   'спросила',
#   'гарри',
#   'хочет',
#   'успели',
#   'утащить',
#   'прочь',
#   'купили',
#   'дешевое',
#   'лимонное',
#   'мороженое'],
#  ['это',
#   'неплохо',
#   'думал',
#   'гарри',
#   'облизывая',
#   'смотрели',
#   'почесывающуюся',
#   'гориллу',
#   'очень',
#   'похожую',
#   'дадли',
#   'всем',
#   'кроме',
#   'цвета',
#   'шерсти'],
#  ['гарри', 'наслаждался', 'этим', 'утром', 'впервые', 'долгое', 'время'],
#  ['осторожно',
#   'шел',
#   'стороне',
#   'дарсли',
#   'дадли',
#   'пирсу',
#   'которым',
#   'начали',
#   'надоедать',
#   'животные',
#   'взбрело',
#   'голову',
#   'заняться',
#   'любимым',
#   'делом',
#   'избиением'],
#  ['поели',
#   'ресторанчике',
#   'зоопарке',
#   'дадли',
#   'разозлился',
#   'славе',
#   'никербокеров',
#   'слишком',
#   'мало',
#   'мороженого',
#   'дядя',
#   'вернон',
#   'купил',
#   'другое',
#   'гарри',
#   'разрешили',
#   'доесть',
#   'это'],
#  ['гарри', 'понял', 'шло', 'слишком', 'продолжаться', 'духе'],
#  ['обеда', 'пошли', 'павильон', 'рептилий'],
#  ['холодно', 'темно', 'окна', 'светились', 'стенах'],
#  ['стеклом',
#   'всевозможные',
#   'ящерицы',
#   'змеи',
#   'ползали',
#   'скользили',
#   'веткам',
#   'деревьев',
#   'камням'],
#  ['дадли',
#   'пирс',
#   'хотели',
#   'посмотреть',
#   'ядовитых',
#   'кобр',
#   'мощных',
#   'питонов'],
#  ['дадли', 'моментально', 'нашел', 'самую', 'большую', 'змею', 'террариуме'],
#  ['могла',
#   'раза',
#   'обернуться',
#   'вокруг',
#   'машины',
#   'дяди',
#   'вернона',
#   'сжать',
#   'размеров',
#   'мусорницы',
#   'выглядела',
#   'настроении'],
#  ['самом', 'деле', 'крепко', 'спала'],
#  ['дадли',
#   'стоял',
#   'прижав',
#   'нос',
#   'стеклу',
#   'глядя',
#   'блестящие',
#   'коричневые',
#   'кольца'],
#  ['заставь', 'ползти', 'хныкал'],
#  ['дядя', 'вернон', 'постучал', 'стеклу', 'змея', 'пошевелилась'],
#  ['приказал', 'дадли'],
#  ['дядя',
#   'вернон',
#   'постучал',
#   'стеклу',
#   'костяшками',
#   'пальцев',
#   'змея',
#   'продолжала',
#   'спать'],
#  ['скука', 'простонал', 'дадли', 'пошаркал', 'прочь'],
#  ['гарри', 'пододвинулся', 'аквариуму', 'пристально', 'посмотрел', 'змею'],
#  ['удивился',
#   'умерла',
#   'скуки',
#   'никого',
#   'кроме',
#   'глупых',
#   'надоедливых',
#   'людей',
#   'стучащих',
#   'стеклу',
#   'целый',
#   'день'],
#  ['это',
#   'хуже',
#   'спать',
#   'чулане',
#   'единственным',
#   'посетителем',
#   'тетя',
#   'петуния',
#   'будившая',
#   'каждый',
#   'день',
#   'крайней',
#   'мере',
#   'мог',
#   'ходить',
#   'дому'],
#  ['змея', 'внезапно', 'открыла', 'маленькие', 'глазки'],
#  ['медленно',
#   'очень',
#   'медленно',
#   'подняла',
#   'голову',
#   'глаза',
#   'находились',
#   'одном',
#   'уровне',
#   'глазами',
#   'гарри'],
#  ['подмигнула'],
#  ['гарри', 'смотрел'],
#  ['быстро',
#   'оглянулся',
#   'взглянуть',
#   'ктонибудь',
#   'смотрит',
#   'никто',
#   'смотрел'],
#  ['повернулся', 'змее', 'подмигнул'],
#  ['змея',
#   'качнула',
#   'головой',
#   'сторону',
#   'дяди',
#   'вернона',
#   'дадли',
#   'подняла',
#   'глаза',
#   'потолку'],
#  ['гарри', 'стало', 'абсолютно', 'понятно', 'хотела', 'сказать', 'время'],
#  ['знаю',
#   'прошептал',
#   'гарри',
#   'сквозь',
#   'стекло',
#   'хотя',
#   'уверен',
#   'змея',
#   'услышит'],
#  ['наверное', 'очень', 'раздражает'],
#  ['змея', 'энергично', 'кивнула'],
#  ['откуда'],
#  ['спросил', 'гарри'],
#  ['змея', 'показала', 'хвостом', 'маленькую', 'табличку', 'рядом', 'стеклом'],
#  ['гарри', 'всмотрелся'],
#  ['удав', 'бразилия'],
#  ['бразилии'],
#  ['удав',
#   'показал',
#   'хвостом',
#   'табличку',
#   'гарри',
#   'прочел',
#   'дальше',
#   'образец',
#   'выведен',
#   'зоопарке',
#   'понятно',
#   'значит',
#   'бразилии'],
#  ['удав',
#   'покачал',
#   'головой',
#   'момент',
#   'раздался',
#   'оглушающий',
#   'вопль',
#   'пирса',
#   'вдвоем',
#   'подпрыгнули',
#   'неожиданности',
#   'дадли'],
#  ['мистер', 'дарсли'],
#  ['идите', 'взгяните', 'змею'],
#  ['поверите', 'делает'],
#  ['дадли', 'вразвалочку', 'заспешил', 'вольеру'],
#  ['дороги', 'сказал', 'ударив', 'гарри', 'бок'],
#  ['застигнутый', 'врасплох', 'гарри', 'упал', 'ударился', 'бетонный', 'пол'],
#  ['следующее',
#   'произошло',
#   'быстро',
#   'никто',
#   'видел',
#   'это',
#   'случилось',
#   'секунда',
#   'пирс',
#   'дадли',
#   'склонились',
#   'стеклу',
#   'сразу',
#   'отпрыгнули',
#   'воплями',
#   'ужаса'],
#  ['гарри', 'сел', 'охнул', 'стекло', 'вольера', 'исчезло'],
#  ['огромная', 'змея', 'быстро', 'скользила', 'пол'],
#  ['люди', 'всему', 'павильону', 'рептилий', 'кричали', 'бежали', 'выходу'],
#  ['змея',
#   'двигалась',
#   'мимо',
#   'гарри',
#   'мог',
#   'поклясться',
#   'низкий',
#   'шипящий',
#   'голос',
#   'произнес',
#   'бразилия',
#   'иду',
#   'ссспасибо',
#   'амиго'],
#  ['служащий', 'террариума', 'шоке'],
#  ['стекло'],
#  ['повторял'],
#  ['делось', 'стекло'],
#  ['директор',
#   'зоопарка',
#   'сделал',
#   'тете',
#   'петунии',
#   'чашку',
#   'горячего',
#   'сладкого',
#   'чая',
#   'извинялся',
#   'извинялся',
#   'снова',
#   'извинялся'],
#  ['пирс', 'дадли', 'могли', 'лишь', 'невнятно', 'бормотать'],
#  ['насколько',
#   'гарри',
#   'понял',
#   'змея',
#   'сделала',
#   'играючи',
#   'укусила',
#   'пятки',
#   'ползла',
#   'мимо',
#   'вернулись',
#   'машину',
#   'дяди',
#   'вернона',
#   'дадли',
#   'убеждал',
#   'откусила',
#   'ногу',
#   'пирс',
#   'клялся',
#   'пыталась',
#   'задушить',
#   'насмерть'],
#  ['хуже',
#   'крайней',
#   'мере',
#   'гарри',
#   'пирс',
#   'немножко',
#   'успокоился',
#   'сказал',
#   'разговаривала',
#   'тобой',
#   'правда',
#   'гарри'],
#  ['дядя',
#   'вернон',
#   'подождал',
#   'пока',
#   'пирс',
#   'покинет',
#   'дом',
#   'наброситься',
#   'гарри'],
#  ['зол', 'мог', 'сказать'],
#  ['удалось',
#   'выдавить',
#   'иди',
#   'чулан',
#   'сиди',
#   'еды',
#   'упал',
#   'стул',
#   'тете',
#   'петунии',
#   'пришлось',
#   'бежать',
#   'большим',
#   'стаканом',
#   'бренди'],
#  ['немного',
#   'спустя',
#   'гарри',
#   'лежал',
#   'темном',
#   'чулане',
#   'мечтая',
#   'иметь',
#   'часы'],
#  ['знал', 'сколько', 'времени', 'уверен', 'дарсли', 'уснули'],
#  ['пока', 'уснут', 'мог', 'рискнуть', 'проскользнуть', 'кухню', 'поесть'],
#  ['жил',
# ...
#   'которые',
#   'хотел',
#   'посмотреть',
#   'разнес',
#   'положенного',
#   'количества',
#   'монстров',
#   'компьютере'],
#  ['дядя',
#   'вернон',
#   'остановился',
#   'около',
#   'унылого',
#   'отеля',
#   'окраине',
#   'большого',
#   'города'],
#  ['дадли',
#   'гарри',
#   'досталась',
#   'комната',
#   'двумя',
#   'кроватями',
#   'затхлыми',
#   'сырыми',
#   'простынями'],
#  ['дадли',
#   'храпел',
#   'гарри',
#   'сидел',
#   'подоконнике',
#   'смотрел',
#   'вниз',
#   'огни',
#   'проезжающих',
#   'машин',
#   'думал',
#   'завтракали',
#   'безвкусными',
#   'кукурузными',
#   'хлопьями',
#   'холодными',
#   'помидорами',
#   'металлическим',
#   'привкусом',
#   'тостах'],
#  ['закончили',
#   'столу',
#   'подошла',
#   'хозяйка',
#   'отеля',
#   'извините',
#   'среди',
#   'мистера',
#   'г',
#   'поттера'],
#  ['конторке', 'сотня', 'писем'],
#  ['протянула',
#   'одно',
#   'смогли',
#   'разобрать',
#   'адрес',
#   'написанный',
#   'зелеными',
#   'чернилами',
#   'мистеру',
#   'г',
#   'поттеру',
#   'комната',
#   '17',
#   'гостиница',
#   'железной',
#   'дороги',
#   'город',
#   'коксовик',
#   'гарри',
#   'потянулся',
#   'письмом',
#   'дядя',
#   'вернон',
#   'ударил',
#   'руке'],
#  ['женщина', 'смотрела', 'удивлением'],
#  ['возьму', 'сказал', 'быстро', 'вставая', 'следуя', 'выходу', 'ресторана'],
#  ['просто', 'поехать', 'домой', 'дорогой'],
#  ['предложила',
#   'тетя',
#   'петуния',
#   'робко',
#   'несколько',
#   'часов',
#   'казалось',
#   'дядя',
#   'вернон',
#   'услышал'],
#  ['никто', 'понимал', 'ищет'],
#  ['привез',
#   'лесную',
#   'чащу',
#   'вышел',
#   'машины',
#   'огляделся',
#   'покачал',
#   'головой',
#   'залез',
#   'обратно',
#   'поехали',
#   'дальше'],
#  ['самое',
#   'произошло',
#   'вспаханном',
#   'поле',
#   'подъемном',
#   'мосту',
#   'верхнем',
#   'ярусе',
#   'многоуровневой',
#   'автостоянки'],
#  ['папа', 'сошел', 'ума', 'мам'],
#  ['спросил', 'дадли', 'скукой', 'голосе', 'позже', 'день'],
#  ['дядя', 'вернон', 'остановился', 'побережье', 'запер', 'машине', 'исчез'],
#  ['пошел', 'дождь'],
#  ['большие', 'капли', 'стучали', 'крыше'],
#  ['дадли', 'захныкал'],
#  ['сегодня', 'понедельник', 'сказал', 'матери'],
#  ['великий', 'гумберто', 'сегодня', 'вечером'],
#  ['хочу', 'рядом', 'телевизором'],
#  ['понедельник'],
#  ['чтото', 'шевельнулось', 'гарри', 'голове'],
#  ['сегодня',
#   'понедельник',
#   'дадли',
#   'обычно',
#   'точно',
#   'знает',
#   'день',
#   'недели',
#   'изза',
#   'телевизора',
#   'завтра',
#   'вторник',
#   'одиннадцатый',
#   'день',
#   'рождения'],
#  ['сказать',
#   'веселые',
#   'дни',
#   'рождения',
#   'прошлом',
#   'году',
#   'дарсли',
#   'подарили',
#   'крючок',
#   'одежды',
#   'пару',
#   'старых',
#   'носок',
#   'дяди',
#   'вернона'],
#  ['каждый', 'день', 'тебе', 'исполняется', 'одиннадцать', 'лет'],
#  ['дядя', 'вернон', 'вернулся', 'улыбаясь'],
#  ['принес',
#   'длинный',
#   'тонкий',
#   'пакет',
#   'ответил',
#   'тетя',
#   'петуния',
#   'спросила',
#   'купил'],
#  ['нашел', 'идеальное', 'место'],
#  ['сказал'],
#  ['пошли'],
#  ['выходите', 'машины'],
#  ['снаружи', 'очень', 'холодно'],
#  ['дядя',
#   'вернон',
#   'кивнул',
#   'сторону',
#   'острова',
#   'похожего',
#   'кусок',
#   'скалы',
#   'море'],
#  ['ютившаяся',
#   'наверху',
#   'скалы',
#   'хижина',
#   'казалась',
#   'самой',
#   'убогой',
#   'представить'],
#  ['сегодня', 'вечером', 'обещают', 'шторм'],
#  ['сказал', 'дядя', 'вернон', 'ликующе', 'хлопая', 'ладоши'],
#  ['джентльмен', 'добр', 'одолжил', 'нам', 'лодку'],
#  ['беззубый',
#   'старичок',
#   'вразвалочку',
#   'подошел',
#   'указывая',
#   'довольно',
#   'неприятной',
#   'усмешкой',
#   'старую',
#   'гребную',
#   'лодку',
#   'подпрыгивающую',
#   'внизу',
#   'серых',
#   'волнах'],
#  ['достал', 'немного', 'еды', 'сказал', 'дядя', 'вернон'],
#  ['свистать', 'наверх'],
#  ['лодке', 'холодно'],
#  ['ледяная',
#   'морская',
#   'вода',
#   'дождь',
#   'стекающий',
#   'шиворот',
#   'промозглый',
#   'ветер',
#   'бьющий',
#   'лицо'],
#  ['казалось',
#   'нескольких',
#   'часов',
#   'достигли',
#   'утеса',
#   'дядя',
#   'вернон',
#   'оступаясь',
#   'поскальзываясь',
#   'повел',
#   'наверх',
#   'несчастной',
#   'хижине'],
#  ['внутри', 'просто', 'ужасно'],
#  ['пахло',
#   'водорослями',
#   'ветер',
#   'свистел',
#   'щели',
#   'деревянных',
#   'стенах',
#   'очаге',
#   'сыро',
#   'пусто'],
#  ['тому', 'хижине', 'две', 'комнаты'],
#  ['немного',
#   'еды',
#   'понимании',
#   'дяди',
#   'вернона',
#   'оказались',
#   'пакетом',
#   'чипсов',
#   'каждого',
#   'четырьмя',
#   'бананами'],
#  ['попытался', 'зажечь', 'огонь', 'пакеты', 'дымили', 'сжимались'],
#  ['парочка', 'писем', 'пригодилась'],
#  ['сказал', 'радостно'],
#  ['очень', 'хорошем', 'настроении'],
#  ['вероятно',
#   'думал',
#   'никто',
#   'сможет',
#   'добраться',
#   'шторм',
#   'доставить',
#   'почту'],
#  ['гарри', 'согласен', 'эта', 'мысль', 'радовала'],
#  ['наступила', 'ночь', 'разразился', 'обещанный', 'шторм'],
#  ['брызги',
#   'высоких',
#   'волн',
#   'разбивались',
#   'стены',
#   'хижины',
#   'яростный',
#   'ветер',
#   'стучал',
#   'грязные',
#   'окна'],
#  ['тетя',
#   'петуния',
#   'нашла',
#   'несколько',
#   'заплесневелых',
#   'одеял',
#   'соседней',
#   'комнате',
#   'сделала',
#   'постель',
#   'дадли',
#   'изъеденном',
#   'молью',
#   'диване'],
#  ['дядя',
#   'вернон',
#   'улеглись',
#   'слежавшиеся',
#   'комками',
#   'матрасы',
#   'второй',
#   'комнате',
#   'гарри',
#   'предоставили',
#   'возможность',
#   'найти',
#   'самый',
#   'мягкий',
#   'кусочек',
#   'пола',
#   'съежиться',
#   'самым',
#   'тонким',
#   'рваным',
#   'одеялом'],
#  ['шторм', 'становился', 'сильнее', 'сильнее'],
#  ['гарри', 'мог', 'уснуть'],
#  ['дрожал',
#   'ворочался',
#   'пытаясь',
#   'устроиться',
#   'поудобнее',
#   'желудок',
#   'сжимался',
#   'голода'],
#  ['храп',
#   'дадли',
#   'тонул',
#   'низких',
#   'раскатах',
#   'грома',
#   'который',
#   'начал',
#   'греметь',
#   'ближе',
#   'полуночи'],
#  ['светящийся',
#   'циферблат',
#   'часов',
#   'дадли',
#   'которые',
#   'свисали',
#   'края',
#   'дивана',
#   'вместе',
#   'толстой',
#   'рукой',
#   'сказал',
#   'гарри',
#   'десять',
#   'минут',
#   'исполнится',
#   'одиннадцать',
#   'лет'],
#  ['лежал',
#   'смотрел',
#   'приближается',
#   'день',
#   'рождения',
#   'любопытствуя',
#   'вспомнят',
#   'дарсли',
#   'нем',
#   'вообще',
#   'думая',
#   'писал',
#   'письма'],
#  ['осталось', 'пять', 'минут'],
#  ['услышал', 'снаружи', 'чтото', 'скрипнуло'],
#  ['надеялся', 'крыша', 'обрушится', 'хотя', 'обрушится', 'станет', 'теплее'],
#  ['четыре', 'минуты'],
#  ['дома', 'писем', 'вернутся', 'удастся', 'какнибудь', 'утащить', 'одно'],
#  ['минуты'],
#  ['почему', 'море', 'громко', 'бьется', 'остров'],
#  ['две', 'минуты', 'это', 'странный', 'хруст', 'дверью'],
#  ['скала', 'рушится', 'море'],
#  ['одна', 'минута', 'одиннадцать'],
#  ['тридцать',
#   'секунд',
#   'двадцать',
#   'десять',
#   'девять',
#   'разбудить',
#   'дадли',
#   'позлить',
#   'две',
#   'одна',
#   'бум'],
#  ['хижина', 'вздрогнула', 'гарри', 'резко', 'сел', 'уставившись', 'дверь'],
#  ['ктото', 'снаружи', 'стучался', 'впустили'],
#  ['глава', 'четвертая', 'хранитель', 'ключей', 'бум'],
#  ['постучал', 'ктото'],
#  ['дадли', 'проснулся'],
#  ['пушка'],
#  ['растерянно', 'спросил'],
#  ['сзади', 'раздался', 'грохот', 'дядя', 'вернон', 'влетел', 'комнату'],
#  ['руках',
#   'держал',
#   'винтовку',
#   'поняли',
#   'длинном',
#   'узком',
#   'свертке',
#   'который',
#   'привез'],
#  [],
#  ['крикнул'],
#  ['предупреждаю', 'вооружен'],
#  ['последовала', 'пауза'],
#  ['громыхнуло',
#   'удар',
#   'настолько',
#   'силен',
#   'дверь',
#   'аккуратно',
#   'слетела',
#   'петель',
#   'оглушительным',
#   'треском',
#   'приземлилась',
#   'пол'],
#  ['дверном', 'проеме', 'появился', 'настоящий', 'великан'],
#  ['лицо',
#   'полностью',
#   'закрыто',
#   'длинными',
#   'косматыми',
#   'волосами',
#   'спутанной',
#   'бородой',
#   'похожие',
#   'темных',
#   'блестящих',
#   'жуков',
#   'глаза',
#   'сверкали',
#   'сквозь',
#   'заросли'],
#  ['великан',
#   'протиснулся',
#   'хижину',
#   'пригнувшись',
#   'голова',
#   'касалась',
#   'потолка'],
#  ['наклонился', 'легко', 'поднял', 'дверь', 'повесил', 'прежнее', 'место'],
#  ['шум', 'грозы', 'стал', 'тише', 'великан', 'оглядел', 'компанию'],
#  ['могли', 'предложить', 'чашечку', 'чая'],
#  ['это',
#   'нелегкое',
#   'путешествие',
#   'прошагал',
#   'дивану',
#   'сидел',
#   'дадли',
#   'скованный',
#   'страхом'],
#  ['подвинься', 'толстяк', 'проговорил', 'незнакомец'],
#  ['дадли',
#   'пискнул',
#   'побежал',
#   'матери',
#   'замершей',
#   'ужаса',
#   'позади',
#   'дяди',
#   'вернона'],
#  ['гарри', 'обрадовался', 'великан'],
#  ['гарри',
#   'взглянул',
#   'дикое',
#   'лицо',
#   'увидел',
#   'глазахжуках',
#   'притаилась',
#   'улыбка'],
#  ['видел', 'последний', 'младенцем', 'сказал', 'великан'],
#  ['похож', 'отца', 'глаза', 'матери'],
#  ['дядя', 'вернон', 'издал', 'странный', 'дребезжащий', 'звук'],
#  ['требую', 'ушли', 'сэр'],
#  ['сказал'],
#  ['нарушаете', 'право', 'частной', 'собственности'],
#  ['заткнись',
#   'дарсли',
#   'сказал',
#   'великан',
#   'перегнулся',
#   'спинку',
#   'дивана',
#   'выхватил',
#   'ружье',
#   'рук',
#   'дяди',
#   'вернона',
#   'завязал',
#   'узлом',
#   'оно',
#   'резиновым',
#   'бросил',
#   'угол',
#   'комнаты'],
#  ['дядя', 'вернон', 'пискнул', 'раздавленная', 'мышь'],
#  ['ладно',
#   'гарри',
#   'бывало',
#   'продолжал',
#   'великан',
#   'поворачиваясь',
#   'спиной',
#   'дарсли',
#   'днем',
#   'рождения'],
#  ['коечто', 'слегка', 'помял', 'вкус', 'замечательный'],
#  ['внутреннего',
#   'кармана',
#   'своего',
#   'черного',
#   'пальто',
#   'достал',
#   'немного',
#   'раздавленную',
#   'коробку'],
#  ['гарри', 'дрожащими', 'пальцами', 'открыл'],
#  ['внутри',
#   'большой',
#   'липкий',
#   'шоколадный',
#   'торт',
#   'надписью',
#   'зеленой',
#   'глазурью',
#   'днем',
#   'рождения',
#   'гарри'],
#  ['гарри', 'взглянул', 'великана'],
#  ['собирался',
#   'поблагодарить',
#   'слова',
#   'гдето',
#   'потерялись',
#   'вместо',
#   'сказал'],
#  ['великан', 'усмехнулся'],
#  ['правда', 'представился'],
#  ['рубеус', 'хагрид', 'хранитель', 'ключей', 'земель', 'хогвартса'],
#  ['протянул', 'огромную', 'ладонь', 'потряс', 'гарри', 'руку'],
#  ['итак', 'насчет', 'чая'],
#  ['сказал', 'потирая', 'руки'],
#  ['отказался', 'очень', 'крепкого'],
#  ['взгляд',
#   'упал',
#   'пустоту',
#   'каминной',
#   'решеткой',
#   'скрученными',
#   'пакетами',
#   'изпод',
#   'чипсов'],
#  ['великан', 'фыркнул'],
#  ['склонился',
#   'камином',
#   'сделал',
#   'никто',
#   'разглядел',
#   'отошел',
#   'секундой',
#   'позже',
#   'пылал',
#   'огонь'],
#  ['наполнил',
#   'сырую',
#   'хижину',
#   'мерцающим',
#   'светом',
#   'гарри',
#   'почувствовал',
#   'проникающее',
#   'тепло',
#   'точно',
#   'оказался',
#   'теплой',
#   'ванне'],
#  ['гигант',
#   'вернулся',
#   'диван',
#   'заскрипевший',
#   'тяжестью',
#   'начал',
#   'доставать',
#   'карманов',
#   'всякую',
#   'всячину',
#   'медный',
#   'котелок',
#   'мягкую',
#   'упаковку',
#   'сосисок',
#   'кочергу',
#   'чайник',
#   'несколько',
#   'отбитых',
#   'кружек',
#   'бутылку',
#   'какойто',
#   'янтарного',
#   'цвета',
#   'жидкостью',
#   'которой',
#   'отхлебнул',
#   'прежде',
#   'запустить',
#   'процесс',
#   'приготовления'],
#  ['скоро',
#   'хижина',
#   'наполнилась',
#   'звуками',
#   'запахом',
#   'жареных',
#   'сосисок'],
#  ['никто',
#   'сказал',
#   'слова',
#   'пока',
#   'великан',
#   'готовил',
#   'снял',
#   'первые',
#   'шесть',
#   'сочных',
#   'подгорелых',
#   'сосисок',
#   'кочерги',
#   'дадли',
#   'заерзал'],
#  ['дядя', 'вернон', 'сказал', 'резко', 'трогай', 'тебе', 'дал', 'дадли'],
#  ['великан', 'усмехнулся'],
#  ['тебе',
#   'пончик',
#   'твоему',
#   'сыночку',
#   'толстеть',
#   'дальше',
#   'некуда',
#   'поэтому',
#   'волнуйся'],
#  ['великан',
#   'передал',
#   'сосиски',
#   'гарри',
#   'который',
#   'проголодался',
#   'казалось',
#   'ел',
#   'вкуснее',
#   'никак',
#   'мог',
#   'отвести',
#   'глаз',
#   'великана'],
#  ['никто',
#   'видимо',
#   'собирался',
#   'объяснять',
#   'гарри',
#   'сказал',
#   'извините',
#   'знаю',
#   'всетаки'],
#  ['великан',
#   'сделал',
#   'глоток',
#   'чаю',
#   'утер',
#   'рот',
#   'тыльной',
#   'стороной',
#   'ладони'],
#  ['зови', 'хагрид', 'сказал'],
#  [],
#  ['сказал', 'хранитель', 'ключей', 'хогвартсе'],
#  ['курсе', 'хогвартс'],
#  ['гм', 'сказал', 'гарри'],
#  ['хагрид', 'шокирован'],
#  ['извините', 'быстро', 'сказал', 'гарри'],
#  ['извинить'],
#  ['пролаял',
#   'хагрид',
#   'поворачиваясь',
#   'дарсли',
#   'отступившим',
#   'обратно',
#   'тень'],
#  ['это', 'должны', 'извиняться'],
#  ['знал', 'получил', 'письма', 'курсе', 'хогвартс'],
#  ['интересовался', 'твои', 'предки', 'всему', 'научились'],
#  ['научились', 'чему'],
#  ['спросил', 'гарри'],
#  ['чему'],
#  ['прогремел', 'хагрид'],
#  ['погоди', 'минутку'],
#  ['поднялся', 'ноги'],
#  ['казалось', 'гневе', 'заполнил', 'хижину'],
#  ['дарсли', 'жались', 'стене'],
#  ['хотите', 'сказать', 'прорычал', 'дарсли', 'мальчик', 'мальчик'],
#  ['знает'],
#  ['гарри', 'подумал', 'хагрид', 'зашел', 'слишком', 'далеко'],
#  ['учился', 'школе', 'оценки', 'очень'],
#  ['коечто', 'знаю', 'сказал'],
#  ['математику', 'например'],
#  ['хагрид',
#   'просто',
#   'махнул',
#   'рукой',
#   'произнес',
#   'наш',
#   'мир',
#   'хочу',
#   'сказать'],
#  ['твой', 'мир'],
#  ['мир'],
#  ['мир', 'твоих', 'родителей'],
#  ['мир'],
#  ['казалось', 'хагрид', 'взорвется'],
#  ['дарсли'],
#  ['взревел'],
#  ['очень',
#   'бледный',
#   'дядя',
#   'вернон',
#   'прошептал',
#   'чтото',
#   'вроде',
#   'мимблвимбл'],
#  ['хагрид', 'дико', 'взглянул', 'гарри'],
#  ['должен', 'знать', 'отца', 'мать', 'сказал'],
#  ['хочу', 'сказать', 'знамениты'],
#  ['знаменит'],
#  [],
#  ['мои', 'мама', 'папа', 'знамениты'],
#  ['знаешь',
#   'знаешь',
#   'хагрид',
#   'запустил',
#   'пятерню',
#   'шевелюру',
#   'устремив',
#   'гарри',
#   'дикий',
#   'взгляд'],
#  ['знаешь'],
#  ['спросил'],
#  ['внезапно', 'дядя', 'вернон', 'подал', 'голос'],
#  ['немедля', 'прекратите'],
#  ['запрещаю', 'рассказывать', 'мальчику'],
#  ['храбрый',
#   'человек',
#   'дядя',
#   'вернон',
#   'дрогнул',
#   'взгляда',
#   'хагрида',
#   'великан',
#   'заговорил',
#   'каждом',
#   'слоге',
#   'звучала',
#   'ярость',
#   'говорили'],
#  ['говорили', 'письме', 'которое', 'оставил', 'дамблдор'],
#  [],
#  ['видел', 'оставил', 'дарсли'],
#  ['сказали', 'годы'],
#  ['сказали'],
#  ['спросил', 'гарри', 'нетерпеливо'],
#  ['стойте'],
#  ['запрещаю'],
#  ['пролаял', 'дядя', 'вернон', 'панике'],
#  ['тетя', 'петуния', 'задохнулась', 'ужаса'],
#  ['идите', 'оба', 'черту', 'сказал', 'хагрид'],
#  ['гарри', 'волшебник'],
#  ['хижине', 'наступила', 'тишина'],
#  ['шумело', 'море', 'свистел', 'ветер'],
#  [],
#  ['выдохнул', 'гарри'],
#  ['волшебник',
#   'сказал',
#   'хагрид',
#   'усаживаясь',
#   'диван',
#   'который',
#   'заскрипел',
#   'просел',
#   'ниже'],
#  ['будешь', 'очень', 'хорошим', 'волшебником', 'подучишься'],
#  ['такими', 'родителями', 'кем', 'можешь'],
#  ['думаю', 'пора', 'прочитать', 'твое', 'письмо'],
#  ['гарри',
#   'вытянул',
#   'руку',
#   'взял',
#   'желтоватый',
#   'конверт',
#   'изумрудно',
#   'зеленой',
#   'надписью',
#   'мистеру',
#   'г',
#   'поттеру',
#   'пол',
#   'хижинанаскале',
#   'море'],
#  ['вытащил',
#   'лист',
#   'прочитал',
#   'школа',
#   'волшебства',
#   'колдовства',
#   'хогвартс',
#   'директор',
#   'альбус',
#   'дамблдор',
#   'орден',
#   'мерлина',
#   'великий',
#   'волш'],
#  ['первого', 'класса', 'главн'],
#  ['колдун', 'верховн'],
#  ['чародей', 'международной', 'конфед'],
#  ['магов', 'дорогой', 'мистер', 'поттер'],
#  ['рады',
#   'сообщить',
#   'приняты',
#   'школу',
#   'волшебства',
#   'колдовства',
#   'хогвартс'],
#  ['пожалуйста',
#   'прочтите',
#   'прилагаемый',
#   'список',
#   'необходимых',
#   'учебников',
#   'оборудования'],
#  ['семестр', 'начинается', 'первого', 'сентября'],
#  ['ждем', 'совы', 'позднее', 'тридцать', 'первого', 'июля'],
#  ['искренне',
#   'ваша',
#   'минерва',
#   'макгонагалл',
#   'заместитель',
#   'директора',
#   'голове',
#   'гарри',
#   'роились',
#   'вопросы',
#   'знал',
#   'задать',
#   'первым'],
#  ['несколько', 'минут', 'произнес', 'запинаясь', 'значит', 'ждут', 'сову'],
#  ['старый',
#   'дурак',
#   'забыл',
#   'сказал',
#   'хагрид',
#   'хлопая',
#   'ладонью',
#   'лбу',
#   'силой',
#   'которая',
#   'могла',
#   'свалить',
#   'лошадь',
#   'вытащил',
#   'какогото',
#   'кармана',
#   'сову',
#   'настоящую',
#   'живую',
#   'немного',
#   'взъерошенную',
#   'сову',
#   'длинное',
#   'перо',
#   'свиток',
#   'пергамента'],
#  ['высунув',
#   'кончик',
#   'языка',
#   'нацарапал',
#   'записку',
#   'которую',
#   'гарри',
#   'прочитал',
#   'вверх',
#   'ногами',
#   'дорогой',
#   'профессор',
#   'дамблдор',
#   'передал',
#   'гарри',
#   'письмо'],
#  ['отвезу', 'завтра', 'купить'],
#  ['ужасная', 'погода'],
#  ['надеюсь', '’', 'кей'],
#  ['хагрид',
#   'хагрид',
#   'свернул',
#   'записку',
#   'отдал',
#   'сове',
#   'которая',
#   'зажала',
#   'клюве',
#   'подошел',
#   'двери',
#   'выбросил',
#   'сову',
#   'шторм'],
#  ['вернулся',
#   'снова',
#   'сел',
#   'это',
#   'такое',
#   'обычное',
#   'дело',
#   'поговорить',
#   'телефону'],
#  ['гарри', 'понял', 'стоит', 'открытым', 'ртом', 'быстро', 'закрыл'],
#  ...]

# %%
len(removed_stopwords)
# Out:
# 6444

# %%
# text = ','.join(removed_stopwords)


removed_stopwords_list = [word  for sent in removed_stopwords for word in sent]
text = ','.join(removed_stopwords_list)

wordcloud = WordCloud(height=1000, width=2000, background_color='white', colormap='rainbow_r').generate(text)
plt.figure( figsize=(20, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# !pip install pymorphy2
# Out:
# Requirement already satisfied: pymorphy2 in d:\github\homework_muiv_iroli\venv\lib\site-packages (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in d:\github\homework_muiv_iroli\venv\lib\site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in d:\github\homework_muiv_iroli\venv\lib\site-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in d:\github\homework_muiv_iroli\venv\lib\site-packages (from pymorphy2) (0.6.2)

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 import pymorphy2
# ----> 2 morph = pymorphy2.MorphAnalyzer()
#
# File d:\GitHub\homework_MUIV_iroli\venv\Lib\site-packages\pymorphy2\analyzer.py:224, in MorphAnalyzer.__init__(self, path, lang, result_type, units, probability_estimator_cls, char_substitutes)
#     222 self._result_type_orig = result_type
#     223 self._init_char_substitutes(char_substitutes)
# --> 224 self._init_units(units)
#
# File d:\GitHub\homework_MUIV_iroli\venv\Lib\site-packages\pymorphy2\analyzer.py:235, in MorphAnalyzer._init_units(self, units_unbound)
#     233 if isinstance(item, (list, tuple)):
#     234     for unit in item[:-1]:
# --> 235         self._units.append((self._bound_unit(unit), False))
#     236     self._units.append((self._bound_unit(item[-1]), True))
#     237 else:
#
# File d:\GitHub\homework_MUIV_iroli\venv\Lib\site-packages\pymorphy2\analyzer.py:246, in MorphAnalyzer._bound_unit(self, unit)
#     245 def _bound_unit(self, unit):
# --> 246     unit = unit.clone()
#     247     unit.init(self)
#     248     return unit
#
# File d:\GitHub\homework_MUIV_iroli\venv\Lib\site-packages\pymorphy2\units\base.py:35, in BaseAnalyzerUnit.clone(self)
#      34 def clone(self):
# ---> 35     return self.__class__(**self._get_params())
#
# File d:\GitHub\homework_MUIV_iroli\venv\Lib\site-packages\pymorphy2\units\base.py:76, in BaseAnalyzerUnit._get_params(self)
#      73 def _get_params(self):
#      74     """ Return a dict with the parameters for this analyzer unit. """
#      75     return dict(
# ---> 76         (key, getattr(self, key, None)) for key in self._get_param_names()
#      77     )
#
# File d:\GitHub\homework_MUIV_iroli\venv\Lib\site-packages\pymorphy2\units\base.py:70, in BaseAnalyzerUnit._get_param_names(cls)
#      68 if cls.__init__ is object.__init__:
#      69     return []
# ---> 70 args, varargs, kw, default = inspect.getargspec(cls.__init__)
#      71 return sorted(args[1:])
#
# AttributeError: module 'inspect' has no attribute 'getargspec'

# %%
removed_stopwords[2766]

# %%
sent_id = 2755
word_id_in_sent = 2
removed_stopwords[sent_id][word_id_in_sent], morph.parse(removed_stopwords[sent_id][word_id_in_sent])[0].normal_form

# %%
morph.parse(removed_stopwords[sent_id][word_id_in_sent])

# %%
morph.parse(removed_stopwords[sent_id][word_id_in_sent])[0].tag

# %%
# lemmatized = [morph.parse(w)[0].normal_form for s in removed_stopwords for w in s]

lemmatized = []

for s in removed_stopwords:
    l = []
    for w in s:
        l.append(morph.parse(w)[0].normal_form)
    lemmatized.append(l)

# %%
lemmatized[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 lemmatized[:10]
#
# NameError: name 'lemmatized' is not defined

# %%
# text = ','.join(lemmatized)
text
for s in lemmatized:
    text += ','.join(s)
    text += '\n'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # text = ','.join(lemmatized)
# ----> 2 text
#       3 for s in lemmatized:
#       4     text += ','.join(s)
#
# NameError: name 'text' is not defined

# %%
preprocessed_file = open('lemmatized_tokens.txt', 'w')
preprocessed_file.write(text)
preprocessed_file.close()

# Checking if the data is
# written to file or not
preprocessed_file = open('lemmatized_tokens.txt', 'r')
print(preprocessed_file.read()[:1000])
preprocessed_file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 preprocessed_file = open('lemmatized_tokens.txt', 'w')
# ----> 2 preprocessed_file.write(text)
#       3 preprocessed_file.close()
#       5 # Checking if the data is
#       6 # written to file or not
#
# NameError: name 'text' is not defined

# %%
wordcloud = WordCloud(height=1000, width=2000, background_color='white', colormap='rainbow_r').generate(text)
plt.figure( figsize=(20, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
